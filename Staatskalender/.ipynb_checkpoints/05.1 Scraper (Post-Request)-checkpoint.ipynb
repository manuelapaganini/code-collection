# %% [markdown]
# # Scraper Post-Request

# %% [markdown]
# Der Reihe nach:
#
# * Url(mit post-zusatz) aufrufen.
# * Dabei Post-Info senden
# * Antwort als Json weiterverarbeiten.
#
# For-Loop:
#
# * Für das Array das zurück kommt eine For-Loop bauen.
# * Darin ein Dictionary aufsetzen, welches die Angaben die mich interessieren Pandas-tauglich macht
# * & Das zu einer Liste hinzufügen.
# * in der For-Loop die sub_url des Eintrags aufrufen (url + id)
# * Mit BeautifulSoup auf die sub_page angucken & die Elemente "legend" abgreifen
# * Das legend-Element das "Herr"/"Frau" enthält zum dictionary hinzufügen.
#
# Die fertige Liste mit Pandas angucken und freuen.

# %%
# Sachen importieren

import requests
import json
import pandas as pd
from bs4 import BeautifulSoup

# %%
# Sachen vorbereiten

data = {'page': '1',
        'pageSize': '1593',
        'mainSearchText': '*'
       }

cookies = {'ASP.NET_SessionId': 'nt4pmcae3gesz4kk41h2lang'}

url = 'http://appl.fr.ch/ate/Person/FilterGridWithIds'


# Zugriff auf die Webseite

response = requests.post(url, data=data, cookies=cookies)

response_as_json = json.loads(response.text)

response_as_json
# Out:
# {'Data': [{'DisplayName': '--- ---',
#    'Email': '',
#    'FirstName': '---',
#    'Id': 96,
#    'LastName': '---',
#    'PhoneNumber': '+41 26 305 12 70',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Staatskanzlei',
#      'Email': '',
#      'Id': 1350,
#      'PhoneNumber': '+41 26 305 12 70',
#      'RoleName': 'Sekretariat',
#      'TitleName': None,
#      'UnitFullName': 'SK - Staatsarchiv',
#      'UnitId': 318,
#      'RoleDenominationId': 1236,
#      'UnitName': 'Staatsarchiv',
#      'Position': 3,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Sekretariat',
#    'UnitsDisplay': 'SK - Staatsarchiv',
#    'UnitsExports': 'Staatsarchiv',
#    'UnitsFullNameExports': 'SK - Staatsarchiv'},
#   {'DisplayName': 'Abeztout Abderrahim',
#    'Email': 'abderrahim.abeztout@fr.ch',
#    'FirstName': 'Abderrahim',
#    'Id': 4423,
#    'LastName': 'Abeztout',
#    'PhoneNumber': '+41 26 305 37 97',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1463608800000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Raumplanungs-, Umwelt- und Baudirektion',
#      'Email': 'abderrahim.abeztout@fr.ch',
#      'Id': 4703,
#      'PhoneNumber': '+41 26 305 37 97',
#      'RoleName': 'Architektin',
#      'TitleName': None,
#      'UnitFullName': 'RUBD - Hochbauamt',
#      'UnitId': 235,
#      'RoleDenominationId': 121,
#      'UnitName': 'Technische Abteilung',
#      'Position': 0,
#      'PublicationStart': '/Date(1463608800000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Architektin',
#    'UnitsDisplay': 'RUBD - Hochbauamt',
#    'UnitsExports': 'Technische Abteilung',
#    'UnitsFullNameExports': 'RUBD - Hochbauamt'},
#   {'DisplayName': 'Ackermann Christophe',
#    'Email': 'christophe.ackermann@fr.ch',
#    'FirstName': 'Christophe',
#    'Id': 1544,
#    'LastName': 'Ackermann',
#    'PhoneNumber': '+41 26 305 31 38',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Finanzdirektion',
#      'Email': 'christophe.ackermann@fr.ch',
#      'Id': 11,
#      'PhoneNumber': '+41 26 305 31 38',
#      'RoleName': 'Adjunkt der Dienstchefin',
#      'TitleName': None,
#      'UnitFullName': 'FIND - Finanzinspektorat',
#      'UnitId': 29,
#      'RoleDenominationId': 15,
#      'UnitName': 'Finanzinspektorat',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Adjunkt der Dienstchefin',
#    'UnitsDisplay': 'FIND - Finanzinspektorat',
#    'UnitsExports': 'Finanzinspektorat',
#    'UnitsFullNameExports': 'FIND - Finanzinspektorat'},
#   {'DisplayName': 'Ackermann Urs',
#    'Email': 'urs.ackermann@fr.ch',
#    'FirstName': 'Urs',
#    'Id': 3557,
#    'LastName': 'Ackermann',
#    'PhoneNumber': '+41 26 305 14 16',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'urs.ackermann@fr.ch',
#      'Id': 1213,
#      'PhoneNumber': '+41 26 305 14 16',
#      'RoleName': 'Höherer Verwaltungssachbearbeiter',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Amt für institutionelle Angelegenheiten, Einbürgerungen und Zivilstandswesen',
#      'UnitId': 895,
#      'RoleDenominationId': 364,
#      'UnitName': 'Abteilung Institutionen und Rechtsangelenheiten',
#      'Position': 3,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Höherer Verwaltungssachbearbeiter',
#    'UnitsDisplay': 'ILFD - Amt für institutionelle Angelegenheiten, Einbürgerungen und Zivilstandswesen',
#    'UnitsExports': 'Abteilung Institutionen und Rechtsangelenheiten',
#    'UnitsFullNameExports': 'ILFD - Amt für institutionelle Angelegenheiten, Einbürgerungen und Zivilstandswesen'},
#   {'DisplayName': 'Adam Samuel',
#    'Email': '',
#    'FirstName': 'Samuel',
#    'Id': 2628,
#    'LastName': 'Adam',
#    'PhoneNumber': '+41 26 305 29 63',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#      'Email': '',
#      'Id': 1890,
#      'PhoneNumber': '+41 26 305 29 63',
#      'RoleName': 'Adjunkt des Dienstchefs',
#      'TitleName': None,
#      'UnitFullName': 'GSD - Kantonsarztamt',
#      'UnitId': 75,
#      'RoleDenominationId': 21,
#      'UnitName': 'Kantonsarztamt',
#      'Position': 5,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Adjunkt des Dienstchefs',
#    'UnitsDisplay': 'GSD - Kantonsarztamt',
#    'UnitsExports': 'Kantonsarztamt',
#    'UnitsFullNameExports': 'GSD - Kantonsarztamt'},
#   {'DisplayName': 'Aebischer Adrian',
#    'Email': 'adrian.aebischer@fr.ch',
#    'FirstName': 'Adrian',
#    'Id': 1289,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 23 43',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'adrian.aebischer@fr.ch',
#      'Id': 3656,
#      'PhoneNumber': '+41 26 305 23 43',
#      'RoleName': 'Wissenschaftlicher Mitarbeiter Waldbiodiversität',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Amt für Wald und Natur',
#      'UnitId': 794,
#      'RoleDenominationId': 392,
#      'UnitName': 'Sektor Faune, Biodiversität, Jagd und Fischerei',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Wissenschaftlicher Mitarbeiter Waldbiodiversität',
#    'UnitsDisplay': 'ILFD - Amt für Wald und Natur',
#    'UnitsExports': 'Sektor Faune, Biodiversität, Jagd und Fischerei',
#    'UnitsFullNameExports': 'ILFD - Amt für Wald und Natur'},
#   {'DisplayName': 'Aebischer Christoph',
#    'Email': '',
#    'FirstName': 'Christoph',
#    'Id': 1580,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 304 14 04',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '0,1',
#    'Roles': [{'DirectionName': 'Volkswirtschaftsdirektion',
#      'Email': '',
#      'Id': 44,
#      'PhoneNumber': '+41 26 304 14 04',
#      'RoleName': 'Projektleiter',
#      'TitleName': None,
#      'UnitFullName': 'VWD - Wirtschaftsförderung Kanton Freiburg',
#      'UnitId': 36,
#      'RoleDenominationId': 237,
#      'UnitName': 'Wirtschaftsförderung Kanton Freiburg',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '0,1',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Projektleiter',
#    'UnitsDisplay': 'VWD - Wirtschaftsförderung Kanton Freiburg',
#    'UnitsExports': 'Wirtschaftsförderung Kanton Freiburg',
#    'UnitsFullNameExports': 'VWD - Wirtschaftsförderung Kanton Freiburg'},
#   {'DisplayName': 'Aebischer Fernand',
#    'Email': 'Non renseigné',
#    'FirstName': 'Fernand',
#    'Id': 36,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '0,1',
#    'Roles': [{'DirectionName': 'Verschiedene',
#      'Email': 'Non renseigné',
#      'Id': 3997,
#      'PhoneNumber': None,
#      'RoleName': 'Kegeln',
#      'TitleName': None,
#      'UnitFullName': 'Vers - Sportvereinigung des Staates Freiburg',
#      'UnitId': 344,
#      'RoleDenominationId': 1011,
#      'UnitName': 'Sportarten',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '0,1',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Kegeln',
#    'UnitsDisplay': 'Vers - Sportvereinigung des Staates Freiburg',
#    'UnitsExports': 'Sportarten',
#    'UnitsFullNameExports': 'Vers - Sportvereinigung des Staates Freiburg'},
#   {'DisplayName': 'Aebischer Florent',
#    'Email': 'florent.aebischer@fr.ch',
#    'FirstName': 'Florent',
#    'Id': 3328,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 44 89',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Volkswirtschaftsdirektion',
#      'Email': 'florent.aebischer@fr.ch',
#      'Id': 981,
#      'PhoneNumber': '+41 26 305 44 89',
#      'RoleName': 'Sekretariat und Schalter',
#      'TitleName': None,
#      'UnitFullName': 'VWD - Handelsregisteramt',
#      'UnitId': 38,
#      'RoleDenominationId': 1856,
#      'UnitName': 'Handelsregisteramt',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Sekretariat und Schalter',
#    'UnitsDisplay': 'VWD - Handelsregisteramt',
#    'UnitsExports': 'Handelsregisteramt',
#    'UnitsFullNameExports': 'VWD - Handelsregisteramt'},
#   {'DisplayName': 'Aebischer Jean-Marc',
#    'Email': '',
#    'FirstName': 'Jean-Marc',
#    'Id': 1038,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 12 61',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1485385200000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': '',
#      'Id': 538,
#      'PhoneNumber': '+41 26 305 12 61',
#      'RoleName': 'Pädagogischer Mitarbeiter',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für Sport',
#      'UnitId': 81,
#      'RoleDenominationId': 381,
#      'UnitName': 'Amt für Sport',
#      'Position': 2,
#      'PublicationStart': '/Date(1485385200000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Pädagogischer Mitarbeiter',
#    'UnitsDisplay': 'EKSD - Amt für Sport',
#    'UnitsExports': 'Amt für Sport',
#    'UnitsFullNameExports': 'EKSD - Amt für Sport'},
#   {'DisplayName': 'Aebischer Jean-Marc',
#    'Email': 'jean-marc.aebischer@fr.ch',
#    'FirstName': 'Jean-Marc',
#    'Id': 4664,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 12 61',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'jean-marc.aebischer@fr.ch',
#      'Id': 4959,
#      'PhoneNumber': '+41 26 305 12 61',
#      'RoleName': 'Körper und Bewegung, Zyklus 1, 2 & 3',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#      'UnitId': 473,
#      'RoleDenominationId': 1606,
#      'UnitName': 'Pädagogische Berater/innen',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Körper und Bewegung, Zyklus 1, 2 & 3',
#    'UnitsDisplay': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#    'UnitsExports': 'Pädagogische Berater/innen',
#    'UnitsFullNameExports': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht'},
#   {'DisplayName': 'Aebischer Jean-Marie',
#    'Email': 'jean-marie.aebischer@fr.oai.ch',
#    'FirstName': 'Jean-Marie',
#    'Id': 609,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 52 40',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '0,1',
#    'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#      'Email': 'jean-marie.aebischer@fr.oai.ch',
#      'Id': 1601,
#      'PhoneNumber': '+41 26 305 52 40',
#      'RoleName': 'sektionschef Zentrale Dienste',
#      'TitleName': None,
#      'UnitFullName': 'GSD - Kantonale Sozialversicherungsanstalt',
#      'UnitId': 220,
#      'RoleDenominationId': 312,
#      'UnitName': 'Invalidenversicherungsstelle',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '0,1',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'sektionschef Zentrale Dienste',
#    'UnitsDisplay': 'GSD - Kantonale Sozialversicherungsanstalt',
#    'UnitsExports': 'Invalidenversicherungsstelle',
#    'UnitsFullNameExports': 'GSD - Kantonale Sozialversicherungsanstalt'},
#   {'DisplayName': 'Aebischer Maryse',
#    'Email': '',
#    'FirstName': 'Maryse',
#    'Id': 755,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 29 68',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '0,1',
#    'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#      'Email': '',
#      'Id': 318,
#      'PhoneNumber': '+41 26 305 29 68',
#      'RoleName': 'Dienstchefin',
#      'TitleName': None,
#      'UnitFullName': 'GSD - Sozialvorsorgeamt',
#      'UnitId': 40,
#      'RoleDenominationId': 339,
#      'UnitName': 'Sozialvorsorgeamt',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '0,1',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Dienstchefin',
#    'UnitsDisplay': 'GSD - Sozialvorsorgeamt',
#    'UnitsExports': 'Sozialvorsorgeamt',
#    'UnitsFullNameExports': 'GSD - Sozialvorsorgeamt'},
#   {'DisplayName': 'Aebischer Mélody',
#    'Email': 'melody.aebischer@fr.ch',
#    'FirstName': 'Mélody',
#    'Id': 4438,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 55 09',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'melody.aebischer@fr.ch',
#      'Id': 4718,
#      'PhoneNumber': '+41 26 305 55 09',
#      'RoleName': 'HR-Fachfrau',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#      'UnitId': 606,
#      'RoleDenominationId': 1271,
#      'UnitName': 'Verwaltung',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'HR-Fachfrau',
#    'UnitsDisplay': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#    'UnitsExports': 'Verwaltung',
#    'UnitsFullNameExports': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg'},
#   {'DisplayName': 'Aebischer Nicolas',
#    'Email': 'nicolas.aebischer@ocms-fribourg.ch',
#    'FirstName': 'Nicolas',
#    'Id': 1035,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 13 90',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'nicolas.aebischer@ocms-fribourg.ch',
#      'Id': 142,
#      'PhoneNumber': '+41 26 305 13 90',
#      'RoleName': 'Direktionsadjunkt',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Kantonale Lehrmittelverwaltung',
#      'UnitId': 50,
#      'RoleDenominationId': 7,
#      'UnitName': 'Kantonale Lehrmittelverwaltung',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Direktionsadjunkt',
#    'UnitsDisplay': 'EKSD - Kantonale Lehrmittelverwaltung',
#    'UnitsExports': 'Kantonale Lehrmittelverwaltung',
#    'UnitsFullNameExports': 'EKSD - Kantonale Lehrmittelverwaltung'},
#   {'DisplayName': 'Aebischer Nicolas',
#    'Email': 'nicolas.aebischer@fr.ch',
#    'FirstName': 'Nicolas',
#    'Id': 1401,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 37 60',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Raumplanungs-, Umwelt- und Baudirektion',
#      'Email': 'nicolas.aebischer@fr.ch',
#      'Id': 1843,
#      'PhoneNumber': '+41 26 305 37 60',
#      'RoleName': 'Sektorchef Wasserkontrollen und Chemikalien',
#      'TitleName': None,
#      'UnitFullName': 'RUBD - Amt für Umwelt',
#      'UnitId': 241,
#      'RoleDenominationId': 1874,
#      'UnitName': 'Sektion Labor und Stoffe',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Sektorchef Wasserkontrollen und Chemikalien',
#    'UnitsDisplay': 'RUBD - Amt für Umwelt',
#    'UnitsExports': 'Sektion Labor und Stoffe',
#    'UnitsFullNameExports': 'RUBD - Amt für Umwelt'},
#   {'DisplayName': 'Aebischer-Aeby Elisabeth',
#    'Email': 'aebischerel@edufr.ch',
#    'FirstName': 'Elisabeth',
#    'Id': 3119,
#    'LastName': 'Aebischer-Aeby',
#    'PhoneNumber': '+41 26 305 79 14',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'aebischerel@edufr.ch',
#      'Id': 3758,
#      'PhoneNumber': '+41 26 305 79 14',
#      'RoleName': 'Vorsteherin',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für Unterricht der Sekundarstufe 2',
#      'UnitId': 274,
#      'RoleDenominationId': 1005,
#      'UnitName': 'Kollegium Gambach',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Vorsteherin',
#    'UnitsDisplay': 'EKSD - Amt für Unterricht der Sekundarstufe 2',
#    'UnitsExports': 'Kollegium Gambach',
#    'UnitsFullNameExports': 'EKSD - Amt für Unterricht der Sekundarstufe 2'},
#   {'DisplayName': 'Aebischer-Piller Christa',
#    'Email': 'christa.aebischer@fr.ch',
#    'FirstName': 'Christa',
#    'Id': 895,
#    'LastName': 'Aebischer-Piller',
#    'PhoneNumber': '+41 26 305 40 88',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'christa.aebischer@fr.ch',
#      'Id': 2030,
#      'PhoneNumber': '+41 26 305 40 88',
#      'RoleName': 'Pädagogische Beraterin: Sprachförderung Eingangsstufe',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht',
#      'UnitId': 485,
#      'RoleDenominationId': 445,
#      'UnitName': 'Pädagogische Mitarbeit',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None},
#     {'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'christa.aebischer@fr.ch',
#      'Id': 1763,
#      'PhoneNumber': '+41 26 305 40 88',
#      'RoleName': 'Inspektorin',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht',
#      'UnitId': 405,
#      'RoleDenominationId': 839,
#      'UnitName': 'Inspektorat für den deutschsprachigen obligatorischen Unterricht, Tafers',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Pädagogische Beraterin: Sprachförderung Eingangsstufe, Inspektorin',
#    'UnitsDisplay': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht, EKSD - Amt für deutschsprachigen obligatorischen Unterricht',
#    'UnitsExports': 'Pädagogische Mitarbeit, Inspektorat für den deutschsprachigen obligatorischen Unterricht, Tafers',
#    'UnitsFullNameExports': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht, EKSD - Amt für deutschsprachigen obligatorischen Unterricht'},
#   {'DisplayName': 'Aeby Annabelle',
#    'Email': '',
#    'FirstName': 'Annabelle',
#    'Id': 1853,
#    'LastName': 'Aeby',
#    'PhoneNumber': '+41 26 305 79 89',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#      'Email': '',
#      'Id': 1160,
#      'PhoneNumber': '+41 26 305 79 89',
#      'RoleName': 'Pflegefachfrau',
#      'TitleName': None,
#      'UnitFullName': 'GSD - Kantonsarztamt',
#      'UnitId': 481,
#      'RoleDenominationId': 778,
#      'UnitName': 'Sektor Pflege',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Pflegefachfrau',
#    'UnitsDisplay': 'GSD - Kantonsarztamt',
#    'UnitsExports': 'Sektor Pflege',
#    'UnitsFullNameExports': 'GSD - Kantonsarztamt'},
#   {'DisplayName': 'Aeby Frédéric',
#    'Email': '',
#    'FirstName': 'Frédéric',
#    'Id': 6508,
#    'LastName': 'Aeby',
#    'PhoneNumber': '+41 26 305 40 85',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1536876000000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': '',
#      'Id': 6867,
#      'PhoneNumber': '+41 26 305 40 85',
#      'RoleName': 'Pädagogischer Mitarbeiter',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht',
#      'UnitId': 485,
#      'RoleDenominationId': 381,
#      'UnitName': 'Pädagogische Mitarbeit',
#      'Position': 7,
#      'PublicationStart': '/Date(1536876000000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Pädagogischer Mitarbeiter',
#    'UnitsDisplay': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht',
#    'UnitsExports': 'Pädagogische Mitarbeit',
#    'UnitsFullNameExports': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht'},
#   {'DisplayName': 'Aeby Pascal',
#    'Email': 'pascal.aeby@fr.ch',
#    'FirstName': 'Pascal',
#    'Id': 1205,
#    'LastName': 'Aeby',
#    'PhoneNumber': '+41 26 305 31 03',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Finanzdirektion',
#      'Email': 'pascal.aeby@fr.ch',
#      'Id': 776,
#      'PhoneNumber': '+41 26 305 31 03',
#      'RoleName': 'Generalsekretär',
#      'TitleName': None,
#      'UnitFullName': 'FIND - Generalsekretariat',
#      'UnitId': 16,
#      'RoleDenominationId': 1218,
#      'UnitName': 'Generalsekretariat',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Generalsekretär',
#    'UnitsDisplay': 'FIND - Generalsekretariat',
#    'UnitsExports': 'Generalsekretariat',
#    'UnitsFullNameExports': 'FIND - Generalsekretariat'},
#   {'DisplayName': 'Aeby Pierre',
#    'Email': 'pierre.aeby@fr.ch',
#    'FirstName': 'Pierre',
#    'Id': 1106,
#    'LastName': 'Aeby',
#    'PhoneNumber': '+41 26 305 58 62',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '0,1',
#    'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'pierre.aeby@fr.ch',
#      'Id': 3874,
#      'PhoneNumber': '+41 26 305 58 62',
#      'RoleName': 'Verantwortlicher für Pflanzenbau',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#      'UnitId': 800,
#      'RoleDenominationId': 1154,
#      'UnitName': 'Pflanzenbau (PB)',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '0,1',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Verantwortlicher für Pflanzenbau',
#    'UnitsDisplay': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#    'UnitsExports': 'Pflanzenbau (PB)',
#    'UnitsFullNameExports': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg'},
#   {'DisplayName': 'Aeby-Barrat Eléonore',
#    'Email': 'eleonore.aeby-barrat@fr.oai.ch',
#    'FirstName': 'Eléonore',
#    'Id': 1895,
#    'LastName': 'Aeby-Barrat',
#    'PhoneNumber': '+41 26 305 52 12',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(1533247200000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#      'Email': 'eleonore.aeby-barrat@fr.oai.ch',
#      'Id': 2042,
#      'PhoneNumber': '+41 26 305 52 12',
#      'RoleName': 'Sektionschefin Rechtsdienst',
#      'TitleName': None,
#      'UnitFullName': 'GSD - Kantonale Sozialversicherungsanstalt',
#      'UnitId': 220,
#      'RoleDenominationId': 1788,
#      'UnitName': 'Invalidenversicherungsstelle',
#      'Position': 0,
#      'PublicationStart': '/Date(1533247200000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Sektionschefin Rechtsdienst',
#    'UnitsDisplay': 'GSD - Kantonale Sozialversicherungsanstalt',
#    'UnitsExports': 'Invalidenversicherungsstelle',
#    'UnitsFullNameExports': 'GSD - Kantonale Sozialversicherungsanstalt'},
#   {'DisplayName': 'Aellen-Rey Fabienne',
#    'Email': 'fabienne.aellen-rey@fr.ch',
#    'FirstName': 'Fabienne',
#    'Id': 1767,
#    'LastName': 'Aellen-Rey',
#    'PhoneNumber': '+41 26 305 22 68',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'fabienne.aellen-rey@fr.ch',
#      'Id': 1511,
#      'PhoneNumber': '+41 26 305 22 68',
#      'RoleName': 'Verwaltungssachbearbeiterin',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Amt für Landwirtschaft',
#      'UnitId': 393,
#      'RoleDenominationId': 424,
#      'UnitName': 'Allgemeine Dienste',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Verwaltungssachbearbeiterin',
#    'UnitsDisplay': 'ILFD - Amt für Landwirtschaft',
#    'UnitsExports': 'Allgemeine Dienste',
#    'UnitsFullNameExports': 'ILFD - Amt für Landwirtschaft'},
#   {'DisplayName': 'Aerne Myriam',
#    'Email': 'Myriam.Aerne@fr.ch',
#    'FirstName': 'Myriam',
#    'Id': 6987,
#    'LastName': 'Aerne',
#    'PhoneNumber': '',
#    'PublicationEnd': '/Date(4094143200000)/',
#    'PublicationStart': '/Date(1569448800000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'Myriam.Aerne@fr.ch',
#      'Id': 7386,
#      'PhoneNumber': None,
#      'RoleName': 'Verantwortliche für Buchbinderei und Konservierung',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für Kultur',
#      'UnitId': 163,
#      'RoleDenominationId': 1917,
#      'UnitName': 'Kantons- und Universitätsbibliothek',
#      'Position': 0,
#      'PublicationStart': '/Date(1569448800000)/',
#      'PublicationEnd': '/Date(4094143200000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Verantwortliche für Buchbinderei und Konservierung',
#    'UnitsDisplay': 'EKSD - Amt für Kultur',
#    'UnitsExports': 'Kantons- und Universitätsbibliothek',
#    'UnitsFullNameExports': 'EKSD - Amt für Kultur'},
#   {'DisplayName': 'Aeschlimann David',
#    'Email': 'david.aeschlimann.sagri@fr.ch',
#    'FirstName': 'David',
#    'Id': 2205,
#    'LastName': 'Aeschlimann',
#    'PhoneNumber': '+41 26 305 23 03',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'david.aeschlimann.sagri@fr.ch',
#      'Id': 6587,
#      'PhoneNumber': '+41 26 305 23 03',
#      'RoleName': 'Regionalverantwortlicher Unterer Saanebezirk',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Amt für Landwirtschaft',
#      'UnitId': 395,
#      'RoleDenominationId': 1725,
#      'UnitName': 'Direktzahlungen',
#      'Position': 2,
#      'PublicationStart': '/Date(1517439600000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None},
#     {'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'david.aeschlimann.sagri@fr.ch',
#      'Id': 2048,
#      'PhoneNumber': '+41 26 305 23 03',
#      'RoleName': 'Sektionschef',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Amt für Landwirtschaft',
#      'UnitId': 393,
#      'RoleDenominationId': 259,
#      'UnitName': 'Allgemeine Dienste',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None},
#     {'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'david.aeschlimann.sagri@fr.ch',
#      'Id': 2237,
#      'PhoneNumber': '+41 26 305 23 03',
#      'RoleName': 'Wissenschaftlicher Berater',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Amt für Landwirtschaft',
#      'UnitId': 397,
#      'RoleDenominationId': 488,
#      'UnitName': 'Produkteförderung, Viehzucht und Weinbau',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Regionalverantwortlicher Unterer Saanebezirk, Sektionschef, Wissenschaftlicher Berater',
#    'UnitsDisplay': 'ILFD - Amt für Landwirtschaft, ILFD - Amt für Landwirtschaft, ILFD - Amt für Landwirtschaft',
#    'UnitsExports': 'Direktzahlungen, Allgemeine Dienste, Produkteförderung, Viehzucht und Weinbau',
#    'UnitsFullNameExports': 'ILFD - Amt für Landwirtschaft, ILFD - Amt für Landwirtschaft, ILFD - Amt für Landwirtschaft'},
#   {'DisplayName': 'Agustoni Clara',
#    'Email': 'clara.agustoni@fr.ch',
#    'FirstName': 'Clara',
#    'Id': 1077,
#    'LastName': 'Agustoni',
#    'PhoneNumber': '+41 26 667 97 96',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'clara.agustoni@fr.ch',
#      'Id': 1924,
#      'PhoneNumber': '+41 26 667 97 96',
#      'RoleName': 'Kon\xadser\xadva\xadto\xadrin',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für Archäologie',
#      'UnitId': 364,
#      'RoleDenominationId': 1381,
#      'UnitName': 'Musée romain de Vallon',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Kon\xadser\xadva\xadto\xadrin',
#    'UnitsDisplay': 'EKSD - Amt für Archäologie',
#    'UnitsExports': 'Musée romain de Vallon',
#    'UnitsFullNameExports': 'EKSD - Amt für Archäologie'},
#   {'DisplayName': 'Ajeti Ismail',
#    'Email': 'Ismail.Ajeti@fr.ch',
#    'FirstName': 'Ismail',
#    'Id': 3416,
#    'LastName': 'Ajeti',
#    'PhoneNumber': '+41 26 305 35 55',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Finanzdirektion',
#      'Email': 'Ismail.Ajeti@fr.ch',
#      'Id': 970,
#      'PhoneNumber': '+41 26 305 35 55',
#      'RoleName': 'Verwaltungsadjunkt',
#      'TitleName': None,
#      'UnitFullName': 'FIND - Amt für Vermessung und Geomatik',
#      'UnitId': 46,
#      'RoleDenominationId': 8,
#      'UnitName': 'Amt für Vermessung und Geomatik',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Verwaltungsadjunkt',
#    'UnitsDisplay': 'FIND - Amt für Vermessung und Geomatik',
#    'UnitsExports': 'Amt für Vermessung und Geomatik',
#    'UnitsFullNameExports': 'FIND - Amt für Vermessung und Geomatik'},
#   {'DisplayName': 'Allemann Aude',
#    'Email': 'aude.allemann@fr.ch',
#    'FirstName': 'Aude',
#    'Id': 5101,
#    'LastName': 'Allemann',
#    'PhoneNumber': '+41 26 305 73 66',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(1513897200000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'aude.allemann@fr.ch',
#      'Id': 5427,
#      'PhoneNumber': '+41 26 305 73 66',
#      'RoleName': 'Coordinatrice',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#      'UnitId': 384,
#      'RoleDenominationId': 1689,
#      'UnitName': 'Koordination für Schüleraustausch des Kantons Freiburg',
#      'Position': 0,
#      'PublicationStart': '/Date(1513897200000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Coordinatrice',
#    'UnitsDisplay': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#    'UnitsExports': 'Koordination für Schüleraustausch des Kantons Freiburg',
#    'UnitsFullNameExports': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht'},
#   {'DisplayName': 'Allemann Aude',
#    'Email': 'aude.allemann@fr.ch',
#    'FirstName': 'Aude',
#    'Id': 5102,
#    'LastName': 'Allemann',
#    'PhoneNumber': '+41 26 305 73 66',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(1513897200000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'aude.allemann@fr.ch',
#      'Id': 5428,
#      'PhoneNumber': '+41 26 305 73 66',
#      'RoleName': 'Coordinatrice',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht',
#      'UnitId': 382,
#      'RoleDenominationId': 1690,
#      'UnitName': 'Koordination für Schüleraustausch des Kantons Freiburg',
#      'Position': 0,
#      'PublicationStart': '/Date(1513897200000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Coordinatrice',
#    'UnitsDisplay': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht',
#    'UnitsExports': 'Koordination für Schüleraustausch des Kantons Freiburg',
#    'UnitsFullNameExports': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht'},
#   {'DisplayName': 'Allemann Aude',
#    'Email': 'aude.allemann@fr.ch',
#    'FirstName': 'Aude',
#    'Id': 6885,
#    'LastName': 'Allemann',
#    'PhoneNumber': '+41 26 305 73 66',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'aude.allemann@fr.ch',
#      'Id': 7282,
#      'PhoneNumber': '+41 26 305 73 66',
#      'RoleName': 'Sprachaustausche',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#      'UnitId': 473,
#      'RoleDenominationId': 1895,
#      'UnitName': 'Pädagogische Berater/innen',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Sprachaustausche',
#    'UnitsDisplay': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#    'UnitsExports': 'Pädagogische Berater/innen',
#    'UnitsFullNameExports': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht'},
#   {'DisplayName': 'Allemann Vincent',
#    'Email': 'vincent.allemann@fr.ch',
#    'FirstName': 'Vincent',
#    'Id': 3726,
#    'LastName': 'Allemann',
#    'PhoneNumber': '+41 26 305 22 61',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'vincent.allemann@fr.ch',
#      'Id': 2182,
#      'PhoneNumber': '+41 26 305 22 61',
#      'RoleName': 'Regionalversantwortlicher Gruyère und Veveyse Süd – Sömmerungsgebiet französischsprachiger Teil',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Amt für Landwirtschaft',
#      'UnitId': 395,
#      'RoleDenominationId': 1736,
#      'UnitName': 'Direktzahlungen',
#      'Position': 3,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Regionalversantwortlicher Gruyère und Veveyse Süd – Sömmerungsgebiet französischsprachiger Teil',
#    'UnitsDisplay': 'ILFD - Amt für Landwirtschaft',
#    'UnitsExports': 'Direktzahlungen',
#    'UnitsFullNameExports': 'ILFD - Amt für Landwirtschaft'},
#   {'DisplayName': 'Amschwand Fabian Max Theodor',
#    'Email': 'fabian.amschwand@unifr.ch',
#    'FirstName': 'Fabian Max Theodor',
#    'Id': 3887,
#    'LastName': 'Amschwand',
#    'PhoneNumber': '+41 26 300 70 04',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1550012400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'fabian.amschwand@unifr.ch',
#      'Id': 2412,
#      'PhoneNumber': '+41 26 300 70 04',
#      'RoleName': 'Generalsekretär',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Universität',
#      'UnitId': 242,
#      'RoleDenominationId': 1218,
#      'UnitName': 'Rektorat',
#      'Position': 2,
#      'PublicationStart': '/Date(1550012400000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Generalsekretär',
#    'UnitsDisplay': 'EKSD - Universität',
#    'UnitsExports': 'Rektorat',
#    'UnitsFullNameExports': 'EKSD - Universität'},
#   {'DisplayName': 'Andenmatten Patrick',
#    'Email': 'patrick.andenmatten@fr.ch',
#    'FirstName': 'Patrick',
#    'Id': 1758,
#    'LastName': 'Andenmatten',
#    'PhoneNumber': '+41 26 305 52 75',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#      'Email': 'patrick.andenmatten@fr.ch',
#      'Id': 1566,
#      'PhoneNumber': '+41 26 305 52 75',
#      'RoleName': 'Wirtschaftswissenschaftlicher Berater, Chef der Finanzabteilung',
#      'TitleName': None,
#      'UnitFullName': 'GSD - Kantonale Sozialversicherungsanstalt',
#      'UnitId': 219,
#      'RoleDenominationId': 1889,
#      'UnitName': 'Kantonale Ausgleichskasse AH/IV/EO',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Wirtschaftswissenschaftlicher Berater, Chef der Finanzabteilung',
#    'UnitsDisplay': 'GSD - Kantonale Sozialversicherungsanstalt',
#    'UnitsExports': 'Kantonale Ausgleichskasse AH/IV/EO',
#    'UnitsFullNameExports': 'GSD - Kantonale Sozialversicherungsanstalt'},
#   {'DisplayName': 'Andrey Colette',
#    'Email': 'colette.andrey@fr.ch',
#    'FirstName': 'Colette',
#    'Id': 626,
#    'LastName': 'Andrey',
#    'PhoneNumber': '+41 26 305 58 53',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'colette.andrey@fr.ch',
#      'Id': 3893,
#      'PhoneNumber': '+41 26 305 58 53',
#      'RoleName': 'Hauswirtschaftliche Beraterin',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#      'UnitId': 802,
#      'RoleDenominationId': 1623,
#      'UnitName': 'Weiterbildung Hauswirtschaft',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Hauswirtschaftliche Beraterin',
#    'UnitsDisplay': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#    'UnitsExports': 'Weiterbildung Hauswirtschaft',
#    'UnitsFullNameExports': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg'},
#   {'DisplayName': 'Andrey Karin',
#    'Email': '',
#    'FirstName': 'Karin',
#    'Id': 1869,
#    'LastName': 'Andrey',
#    'PhoneNumber': '+41 26 305 22 04',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': '',
#      'Id': 250,
#      'PhoneNumber': '+41 26 305 22 04',
#      'RoleName': 'Übersetzerin',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Generalsekretariat',
#      'UnitId': 92,
#      'RoleDenominationId': 1313,
#      'UnitName': 'Generalsekretariat',
#      'Position': 12,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Übersetzerin',
#    'UnitsDisplay': 'ILFD - Generalsekretariat',
#    'UnitsExports': 'Generalsekretariat',
#    'UnitsFullNameExports': 'ILFD - Generalsekretariat'},
#   {'DisplayName': 'Andrey Nicole',
#    'Email': 'nicole.andrey@fr.ch',
#    'FirstName': 'Nicole',
#    'Id': 3543,
#    'LastName': 'Andrey',
#    'PhoneNumber': '+41 26 305 23 43',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'nicole.andrey@fr.ch',
#      'Id': 3637,
#      'PhoneNumber': '+41 26 305 23 43',
#      'RoleName': 'Verwaltungssachbearbeiterin',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Amt für Wald und Natur',
#      'UnitId': 790,
#      'RoleDenominationId': 424,
#      'UnitName': 'Sektor Verwaltung und Finanzen',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Verwaltungssachbearbeiterin',
#    'UnitsDisplay': 'ILFD - Amt für Wald und Natur',
#    'UnitsExports': 'Sektor Verwaltung und Finanzen',
#    'UnitsFullNameExports': 'ILFD - Amt für Wald und Natur'},
#   {'DisplayName': 'Andrey Patrik',
#    'Email': 'patrik.andrey@fr.ch',
#    'FirstName': 'Patrik',
#    'Id': 6288,
#    'LastName': 'Andrey',
#    'PhoneNumber': '+41 26 304 16 21',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1519858800000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'patrik.andrey@fr.ch',
#      'Id': 6630,
#      'PhoneNumber': '+41 26 304 16 21',
#      'RoleName': 'Verwalter',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für Sport',
#      'UnitId': 974,
#      'RoleDenominationId': 1743,
#      'UnitName': 'Campus Schwarzsee',
#      'Position': 1,
#      'PublicationStart': '/Date(1519858800000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Verwalter',
#    'UnitsDisplay': 'EKSD - Amt für Sport',
#    'UnitsExports': 'Campus Schwarzsee',
#    'UnitsFullNameExports': 'EKSD - Amt für Sport'},
#   {'DisplayName': 'Andric Josip',
#    'Email': '',
#    'FirstName': 'Josip',
#    'Id': 6502,
#    'LastName': 'Andric',
#    'PhoneNumber': '+41 26 305 46 24',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(1535925600000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#      'Email': '',
#      'Id': 6860,
#      'PhoneNumber': '+41 26 305 46 24',
#      'RoleName': 'Wirtschaftswissenschaftler',
#      'TitleName': None,
#      'UnitFullName': 'GSD - Sozialvorsorgeamt',
#      'UnitId': 221,
#      'RoleDenominationId': 1804,
#      'UnitName': 'Sondereinrichtungen',
#      'Position': 0,
#      'PublicationStart': '/Date(1535925600000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Wirtschaftswissenschaftler',
#    'UnitsDisplay': 'GSD - Sozialvorsorgeamt',
#    'UnitsExports': 'Sondereinrichtungen',
#    'UnitsFullNameExports': 'GSD - Sozialvorsorgeamt'},
#   {'DisplayName': 'Angéloz Carole',
#    'Email': 'carole.angeloz@fr.ch',
#    'FirstName': 'Carole',
#    'Id': 1537,
#    'LastName': 'Angéloz',
#    'PhoneNumber': '+41 26 305 73 68',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'carole.angeloz@fr.ch',
#      'Id': 2113,
#      'PhoneNumber': '+41 26 305 73 68',
#      'RoleName': 'Schulinspektorin',
#      'TitleName': None,
# ...
#    'Roles': [{'DirectionName': 'Volkswirtschaftsdirektion',
#      'Email': 'Monneyc03@edufr.ch',
#      'Id': 4530,
#      'PhoneNumber': '+41 26 305 25 27',
#      'RoleName': 'Sekretärin',
#      'TitleName': None,
#      'UnitFullName': 'VWD - Amt für Berufsbildung',
#      'UnitId': 126,
#      'RoleDenominationId': 1200,
#      'UnitName': 'Kaufmännische Berufsfachschule',
#      'Position': 0,
#      'PublicationStart': '/Date(1451602800000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Sekretärin',
#    'UnitsDisplay': 'VWD - Amt für Berufsbildung',
#    'UnitsExports': 'Kaufmännische Berufsfachschule',
#    'UnitsFullNameExports': 'VWD - Amt für Berufsbildung'},
#   {'DisplayName': 'Monney Jean-Blaise',
#    'Email': 'jean-blaise.monney@fr.ch',
#    'FirstName': 'Jean-Blaise',
#    'Id': 2142,
#    'LastName': 'Monney',
#    'PhoneNumber': '+41 26 305 23 43, +41 26 305 55 33',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'jean-blaise.monney@fr.ch',
#      'Id': 3643,
#      'PhoneNumber': '+41 26 305 23 43',
#      'RoleName': 'Bibliothekar',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Amt für Wald und Natur',
#      'UnitId': 790,
#      'RoleDenominationId': 1454,
#      'UnitName': 'Sektor Verwaltung und Finanzen',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None},
#     {'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'jean-blaise.monney@fr.ch',
#      'Id': 3216,
#      'PhoneNumber': '+41 26 305 55 33',
#      'RoleName': 'Bibliothekar',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#      'UnitId': 606,
#      'RoleDenominationId': 1454,
#      'UnitName': 'Verwaltung',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Bibliothekar, Bibliothekar',
#    'UnitsDisplay': 'ILFD - Amt für Wald und Natur, ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#    'UnitsExports': 'Sektor Verwaltung und Finanzen, Verwaltung',
#    'UnitsFullNameExports': 'ILFD - Amt für Wald und Natur, ILFD - Landwirtschaftliches Institut des Kantons Freiburg'},
#   {'DisplayName': 'Monney Jean-Marc',
#    'Email': 'jean-marc.monney@fr.ch',
#    'FirstName': 'Jean-Marc',
#    'Id': 490,
#    'LastName': 'Monney',
#    'PhoneNumber': '+41 26 305 38 79',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Raumplanungs-, Umwelt- und Baudirektion',
#      'Email': 'jean-marc.monney@fr.ch',
#      'Id': 2902,
#      'PhoneNumber': '+41 26 305 38 79',
#      'RoleName': 'Technischer Sachbearbeiter',
#      'TitleName': None,
#      'UnitFullName': 'RUBD - Tiefbauamt',
#      'UnitId': 704,
#      'RoleDenominationId': 406,
#      'UnitName': 'Überwachung und Planung von Kunstbauten',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Technischer Sachbearbeiter',
#    'UnitsDisplay': 'RUBD - Tiefbauamt',
#    'UnitsExports': 'Überwachung und Planung von Kunstbauten',
#    'UnitsFullNameExports': 'RUBD - Tiefbauamt'},
#   {'DisplayName': 'Monney Maria-Elena',
#    'Email': 'direction.ep.salesvaulruz@fr.educanet2.ch',
#    'FirstName': 'Maria-Elena',
#    'Id': 4090,
#    'LastName': 'Monney',
#    'PhoneNumber': '+41 26 913 04 10',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1441922400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'direction.ep.salesvaulruz@fr.educanet2.ch',
#      'Id': 4332,
#      'PhoneNumber': '+41 26 913 04 10',
#      'RoleName': 'Schulleiter-in',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#      'UnitId': 875,
#      'RoleDenominationId': 1428,
#      'UnitName': 'PS Sâles, Vaulruz',
#      'Position': 0,
#      'PublicationStart': '/Date(1441922400000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Schulleiter-in',
#    'UnitsDisplay': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#    'UnitsExports': 'PS Sâles, Vaulruz',
#    'UnitsFullNameExports': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht'},
#   {'DisplayName': 'Monney Pierre',
#    'Email': 'pierre.monney@fr.ch',
#    'FirstName': 'Pierre',
#    'Id': 1653,
#    'LastName': 'Monney',
#    'PhoneNumber': '+41 26 305 55 79',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '0,1',
#    'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'pierre.monney@fr.ch',
#      'Id': 3906,
#      'PhoneNumber': '+41 26 305 55 79',
#      'RoleName': 'Lehrer Allgemeinbildung',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#      'UnitId': 804,
#      'RoleDenominationId': 673,
#      'UnitName': 'Ausbildung Hauswirtschaft dual',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '0,1',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Lehrer Allgemeinbildung',
#    'UnitsDisplay': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#    'UnitsExports': 'Ausbildung Hauswirtschaft dual',
#    'UnitsFullNameExports': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg'},
#   {'DisplayName': 'Monney Regina',
#    'Email': 'regina.monney@fr.ch',
#    'FirstName': 'Regina',
#    'Id': 1777,
#    'LastName': 'Monney',
#    'PhoneNumber': '+41 26 305 23 43',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'regina.monney@fr.ch',
#      'Id': 3640,
#      'PhoneNumber': '+41 26 305 23 43',
#      'RoleName': 'Sekretärin',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Amt für Wald und Natur',
#      'UnitId': 790,
#      'RoleDenominationId': 1200,
#      'UnitName': 'Sektor Verwaltung und Finanzen',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Sekretärin',
#    'UnitsDisplay': 'ILFD - Amt für Wald und Natur',
#    'UnitsExports': 'Sektor Verwaltung und Finanzen',
#    'UnitsFullNameExports': 'ILFD - Amt für Wald und Natur'},
#   {'DisplayName': 'Monney Sandrine',
#    'Email': '',
#    'FirstName': 'Sandrine',
#    'Id': 2173,
#    'LastName': 'Monney',
#    'PhoneNumber': '+41 26 305 98 00',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#      'Email': '',
#      'Id': 1362,
#      'PhoneNumber': '+41 26 305 98 00',
#      'RoleName': 'Dentalassistentin',
#      'TitleName': None,
#      'UnitFullName': 'GSD - Schulzahnpflegedienst',
#      'UnitId': 304,
#      'RoleDenominationId': 146,
#      'UnitName': 'Zahnklinik Freiburg',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Dentalassistentin',
#    'UnitsDisplay': 'GSD - Schulzahnpflegedienst',
#    'UnitsExports': 'Zahnklinik Freiburg',
#    'UnitsFullNameExports': 'GSD - Schulzahnpflegedienst'},
#   {'DisplayName': 'Monnier Jacques',
#    'Email': 'jacques.monnier@fr.ch',
#    'FirstName': 'Jacques',
#    'Id': 1587,
#    'LastName': 'Monnier',
#    'PhoneNumber': '+41 26 305 82 42',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'jacques.monnier@fr.ch',
#      'Id': 1617,
#      'PhoneNumber': '+41 26 305 82 42',
#      'RoleName': 'Sektorchef Gallo-römisch',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für Archäologie',
#      'UnitId': 346,
#      'RoleDenominationId': 250,
#      'UnitName': 'Ausgrabungen, Forschungen und Publikationen',
#      'Position': 3,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Sektorchef Gallo-römisch',
#    'UnitsDisplay': 'EKSD - Amt für Archäologie',
#    'UnitsExports': 'Ausgrabungen, Forschungen und Publikationen',
#    'UnitsFullNameExports': 'EKSD - Amt für Archäologie'},
#   {'DisplayName': 'Monpays Christine',
#    'Email': 'direction.ep.granges-paccot@fr.educanet2.ch',
#    'FirstName': 'Christine',
#    'Id': 6419,
#    'LastName': 'Monpays',
#    'PhoneNumber': '+41 26 460 68 41',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1441922400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'direction.ep.granges-paccot@fr.educanet2.ch',
#      'Id': 6772,
#      'PhoneNumber': '+41 26 460 68 41',
#      'RoleName': 'Schulleiter-in',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#      'UnitId': 848,
#      'RoleDenominationId': 1428,
#      'UnitName': 'PS Granges-Paccot - La Sonnaz',
#      'Position': 0,
#      'PublicationStart': '/Date(1441922400000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Schulleiter-in',
#    'UnitsDisplay': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#    'UnitsExports': 'PS Granges-Paccot - La Sonnaz',
#    'UnitsFullNameExports': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht'},
#   {'DisplayName': 'Monterrubio Leu Cristina',
#    'Email': '',
#    'FirstName': 'Cristina',
#    'Id': 4418,
#    'LastName': 'Monterrubio Leu',
#    'PhoneNumber': '+41 26 305 79 92',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1463004000000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#      'Email': '',
#      'Id': 4697,
#      'PhoneNumber': '+41 26 305 79 92',
#      'RoleName': 'Wissenschaftliche Mitarbeiterin',
#      'TitleName': None,
#      'UnitFullName': 'GSD - Kantonsarztamt',
#      'UnitId': 483,
#      'RoleDenominationId': 448,
#      'UnitName': 'Sektor Wissenschaftliche Mitarbeit',
#      'Position': 2,
#      'PublicationStart': '/Date(1463004000000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Wissenschaftliche Mitarbeiterin',
#    'UnitsDisplay': 'GSD - Kantonsarztamt',
#    'UnitsExports': 'Sektor Wissenschaftliche Mitarbeit',
#    'UnitsFullNameExports': 'GSD - Kantonsarztamt'},
#   {'DisplayName': 'Mooser Coumba',
#    'Email': 'coumba.mooser@fr.ch',
#    'FirstName': 'Coumba',
#    'Id': 6289,
#    'LastName': 'Mooser',
#    'PhoneNumber': '+41 26 304 16 27',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1519858800000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#      'Email': 'coumba.mooser@fr.ch',
#      'Id': 6631,
#      'PhoneNumber': '+41 26 304 16 27',
#      'RoleName': 'Verwaltungsangestellte',
#      'TitleName': None,
#      'UnitFullName': 'EKSD - Amt für Sport',
#      'UnitId': 974,
#      'RoleDenominationId': 1593,
#      'UnitName': 'Campus Schwarzsee',
#      'Position': 2,
#      'PublicationStart': '/Date(1519858800000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Verwaltungsangestellte',
#    'UnitsDisplay': 'EKSD - Amt für Sport',
#    'UnitsExports': 'Campus Schwarzsee',
#    'UnitsFullNameExports': 'EKSD - Amt für Sport'},
#   {'DisplayName': 'Morand Monique',
#    'Email': 'Monique.Morand@fr.ch',
#    'FirstName': 'Monique',
#    'Id': 829,
#    'LastName': 'Morand',
#    'PhoneNumber': '+41 26 305 36 41',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Raumplanungs-, Umwelt- und Baudirektion',
#      'Email': 'Monique.Morand@fr.ch',
#      'Id': 1626,
#      'PhoneNumber': '+41 26 305 36 41',
#      'RoleName': 'Sektionschefin',
#      'TitleName': None,
#      'UnitFullName': 'RUBD - Tiefbauamt',
#      'UnitId': 210,
#      'RoleDenominationId': 335,
#      'UnitName': 'Verwaltung (Verw)',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None},
#     {'DirectionName': 'Raumplanungs-, Umwelt- und Baudirektion',
#      'Email': 'Monique.Morand@fr.ch',
#      'Id': 2469,
#      'PhoneNumber': '+41 26 305 36 41',
#      'RoleName': 'Sektionschefin',
#      'TitleName': None,
#      'UnitFullName': 'RUBD - Tiefbauamt',
#      'UnitId': 690,
#      'RoleDenominationId': 335,
#      'UnitName': 'Personal',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Sektionschefin, Sektionschefin',
#    'UnitsDisplay': 'RUBD - Tiefbauamt, RUBD - Tiefbauamt',
#    'UnitsExports': 'Verwaltung (Verw), Personal',
#    'UnitsFullNameExports': 'RUBD - Tiefbauamt, RUBD - Tiefbauamt'},
#   {'DisplayName': 'Morel Bernard',
#    'Email': 'bernard.morel@fr.ch',
#    'FirstName': 'Bernard',
#    'Id': 1811,
#    'LastName': 'Morel',
#    'PhoneNumber': '+41 26 305 55 10',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#      'Email': 'bernard.morel@fr.ch',
#      'Id': 2552,
#      'PhoneNumber': '+41 26 305 55 10',
#      'RoleName': 'Chefbuchhalter',
#      'TitleName': None,
#      'UnitFullName': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#      'UnitId': 514,
#      'RoleDenominationId': 194,
#      'UnitName': 'Buchhaltung',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Chefbuchhalter',
#    'UnitsDisplay': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#    'UnitsExports': 'Buchhaltung',
#    'UnitsFullNameExports': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg'},
#   ...],
#  'Total': 1593,
#  'AggregateResults': None,
#  'Errors': None}

# %%
# Zugreifen auf 'Data'
response_as_json['Data']
# Out:
# [{'DisplayName': '--- ---',
#   'Email': '',
#   'FirstName': '---',
#   'Id': 96,
#   'LastName': '---',
#   'PhoneNumber': '+41 26 305 12 70',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Staatskanzlei',
#     'Email': '',
#     'Id': 1350,
#     'PhoneNumber': '+41 26 305 12 70',
#     'RoleName': 'Sekretariat',
#     'TitleName': None,
#     'UnitFullName': 'SK - Staatsarchiv',
#     'UnitId': 318,
#     'RoleDenominationId': 1236,
#     'UnitName': 'Staatsarchiv',
#     'Position': 3,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Sekretariat',
#   'UnitsDisplay': 'SK - Staatsarchiv',
#   'UnitsExports': 'Staatsarchiv',
#   'UnitsFullNameExports': 'SK - Staatsarchiv'},
#  {'DisplayName': 'Abeztout Abderrahim',
#   'Email': 'abderrahim.abeztout@fr.ch',
#   'FirstName': 'Abderrahim',
#   'Id': 4423,
#   'LastName': 'Abeztout',
#   'PhoneNumber': '+41 26 305 37 97',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1463608800000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Raumplanungs-, Umwelt- und Baudirektion',
#     'Email': 'abderrahim.abeztout@fr.ch',
#     'Id': 4703,
#     'PhoneNumber': '+41 26 305 37 97',
#     'RoleName': 'Architektin',
#     'TitleName': None,
#     'UnitFullName': 'RUBD - Hochbauamt',
#     'UnitId': 235,
#     'RoleDenominationId': 121,
#     'UnitName': 'Technische Abteilung',
#     'Position': 0,
#     'PublicationStart': '/Date(1463608800000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Architektin',
#   'UnitsDisplay': 'RUBD - Hochbauamt',
#   'UnitsExports': 'Technische Abteilung',
#   'UnitsFullNameExports': 'RUBD - Hochbauamt'},
#  {'DisplayName': 'Ackermann Christophe',
#   'Email': 'christophe.ackermann@fr.ch',
#   'FirstName': 'Christophe',
#   'Id': 1544,
#   'LastName': 'Ackermann',
#   'PhoneNumber': '+41 26 305 31 38',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Finanzdirektion',
#     'Email': 'christophe.ackermann@fr.ch',
#     'Id': 11,
#     'PhoneNumber': '+41 26 305 31 38',
#     'RoleName': 'Adjunkt der Dienstchefin',
#     'TitleName': None,
#     'UnitFullName': 'FIND - Finanzinspektorat',
#     'UnitId': 29,
#     'RoleDenominationId': 15,
#     'UnitName': 'Finanzinspektorat',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Adjunkt der Dienstchefin',
#   'UnitsDisplay': 'FIND - Finanzinspektorat',
#   'UnitsExports': 'Finanzinspektorat',
#   'UnitsFullNameExports': 'FIND - Finanzinspektorat'},
#  {'DisplayName': 'Ackermann Urs',
#   'Email': 'urs.ackermann@fr.ch',
#   'FirstName': 'Urs',
#   'Id': 3557,
#   'LastName': 'Ackermann',
#   'PhoneNumber': '+41 26 305 14 16',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'urs.ackermann@fr.ch',
#     'Id': 1213,
#     'PhoneNumber': '+41 26 305 14 16',
#     'RoleName': 'Höherer Verwaltungssachbearbeiter',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Amt für institutionelle Angelegenheiten, Einbürgerungen und Zivilstandswesen',
#     'UnitId': 895,
#     'RoleDenominationId': 364,
#     'UnitName': 'Abteilung Institutionen und Rechtsangelenheiten',
#     'Position': 3,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Höherer Verwaltungssachbearbeiter',
#   'UnitsDisplay': 'ILFD - Amt für institutionelle Angelegenheiten, Einbürgerungen und Zivilstandswesen',
#   'UnitsExports': 'Abteilung Institutionen und Rechtsangelenheiten',
#   'UnitsFullNameExports': 'ILFD - Amt für institutionelle Angelegenheiten, Einbürgerungen und Zivilstandswesen'},
#  {'DisplayName': 'Adam Samuel',
#   'Email': '',
#   'FirstName': 'Samuel',
#   'Id': 2628,
#   'LastName': 'Adam',
#   'PhoneNumber': '+41 26 305 29 63',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#     'Email': '',
#     'Id': 1890,
#     'PhoneNumber': '+41 26 305 29 63',
#     'RoleName': 'Adjunkt des Dienstchefs',
#     'TitleName': None,
#     'UnitFullName': 'GSD - Kantonsarztamt',
#     'UnitId': 75,
#     'RoleDenominationId': 21,
#     'UnitName': 'Kantonsarztamt',
#     'Position': 5,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Adjunkt des Dienstchefs',
#   'UnitsDisplay': 'GSD - Kantonsarztamt',
#   'UnitsExports': 'Kantonsarztamt',
#   'UnitsFullNameExports': 'GSD - Kantonsarztamt'},
#  {'DisplayName': 'Aebischer Adrian',
#   'Email': 'adrian.aebischer@fr.ch',
#   'FirstName': 'Adrian',
#   'Id': 1289,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 23 43',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'adrian.aebischer@fr.ch',
#     'Id': 3656,
#     'PhoneNumber': '+41 26 305 23 43',
#     'RoleName': 'Wissenschaftlicher Mitarbeiter Waldbiodiversität',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Amt für Wald und Natur',
#     'UnitId': 794,
#     'RoleDenominationId': 392,
#     'UnitName': 'Sektor Faune, Biodiversität, Jagd und Fischerei',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Wissenschaftlicher Mitarbeiter Waldbiodiversität',
#   'UnitsDisplay': 'ILFD - Amt für Wald und Natur',
#   'UnitsExports': 'Sektor Faune, Biodiversität, Jagd und Fischerei',
#   'UnitsFullNameExports': 'ILFD - Amt für Wald und Natur'},
#  {'DisplayName': 'Aebischer Christoph',
#   'Email': '',
#   'FirstName': 'Christoph',
#   'Id': 1580,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 304 14 04',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '0,1',
#   'Roles': [{'DirectionName': 'Volkswirtschaftsdirektion',
#     'Email': '',
#     'Id': 44,
#     'PhoneNumber': '+41 26 304 14 04',
#     'RoleName': 'Projektleiter',
#     'TitleName': None,
#     'UnitFullName': 'VWD - Wirtschaftsförderung Kanton Freiburg',
#     'UnitId': 36,
#     'RoleDenominationId': 237,
#     'UnitName': 'Wirtschaftsförderung Kanton Freiburg',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '0,1',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Projektleiter',
#   'UnitsDisplay': 'VWD - Wirtschaftsförderung Kanton Freiburg',
#   'UnitsExports': 'Wirtschaftsförderung Kanton Freiburg',
#   'UnitsFullNameExports': 'VWD - Wirtschaftsförderung Kanton Freiburg'},
#  {'DisplayName': 'Aebischer Fernand',
#   'Email': 'Non renseigné',
#   'FirstName': 'Fernand',
#   'Id': 36,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '0,1',
#   'Roles': [{'DirectionName': 'Verschiedene',
#     'Email': 'Non renseigné',
#     'Id': 3997,
#     'PhoneNumber': None,
#     'RoleName': 'Kegeln',
#     'TitleName': None,
#     'UnitFullName': 'Vers - Sportvereinigung des Staates Freiburg',
#     'UnitId': 344,
#     'RoleDenominationId': 1011,
#     'UnitName': 'Sportarten',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '0,1',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Kegeln',
#   'UnitsDisplay': 'Vers - Sportvereinigung des Staates Freiburg',
#   'UnitsExports': 'Sportarten',
#   'UnitsFullNameExports': 'Vers - Sportvereinigung des Staates Freiburg'},
#  {'DisplayName': 'Aebischer Florent',
#   'Email': 'florent.aebischer@fr.ch',
#   'FirstName': 'Florent',
#   'Id': 3328,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 44 89',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Volkswirtschaftsdirektion',
#     'Email': 'florent.aebischer@fr.ch',
#     'Id': 981,
#     'PhoneNumber': '+41 26 305 44 89',
#     'RoleName': 'Sekretariat und Schalter',
#     'TitleName': None,
#     'UnitFullName': 'VWD - Handelsregisteramt',
#     'UnitId': 38,
#     'RoleDenominationId': 1856,
#     'UnitName': 'Handelsregisteramt',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Sekretariat und Schalter',
#   'UnitsDisplay': 'VWD - Handelsregisteramt',
#   'UnitsExports': 'Handelsregisteramt',
#   'UnitsFullNameExports': 'VWD - Handelsregisteramt'},
#  {'DisplayName': 'Aebischer Jean-Marc',
#   'Email': '',
#   'FirstName': 'Jean-Marc',
#   'Id': 1038,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 12 61',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1485385200000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': '',
#     'Id': 538,
#     'PhoneNumber': '+41 26 305 12 61',
#     'RoleName': 'Pädagogischer Mitarbeiter',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für Sport',
#     'UnitId': 81,
#     'RoleDenominationId': 381,
#     'UnitName': 'Amt für Sport',
#     'Position': 2,
#     'PublicationStart': '/Date(1485385200000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Pädagogischer Mitarbeiter',
#   'UnitsDisplay': 'EKSD - Amt für Sport',
#   'UnitsExports': 'Amt für Sport',
#   'UnitsFullNameExports': 'EKSD - Amt für Sport'},
#  {'DisplayName': 'Aebischer Jean-Marc',
#   'Email': 'jean-marc.aebischer@fr.ch',
#   'FirstName': 'Jean-Marc',
#   'Id': 4664,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 12 61',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'jean-marc.aebischer@fr.ch',
#     'Id': 4959,
#     'PhoneNumber': '+41 26 305 12 61',
#     'RoleName': 'Körper und Bewegung, Zyklus 1, 2 & 3',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#     'UnitId': 473,
#     'RoleDenominationId': 1606,
#     'UnitName': 'Pädagogische Berater/innen',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Körper und Bewegung, Zyklus 1, 2 & 3',
#   'UnitsDisplay': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#   'UnitsExports': 'Pädagogische Berater/innen',
#   'UnitsFullNameExports': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht'},
#  {'DisplayName': 'Aebischer Jean-Marie',
#   'Email': 'jean-marie.aebischer@fr.oai.ch',
#   'FirstName': 'Jean-Marie',
#   'Id': 609,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 52 40',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '0,1',
#   'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#     'Email': 'jean-marie.aebischer@fr.oai.ch',
#     'Id': 1601,
#     'PhoneNumber': '+41 26 305 52 40',
#     'RoleName': 'sektionschef Zentrale Dienste',
#     'TitleName': None,
#     'UnitFullName': 'GSD - Kantonale Sozialversicherungsanstalt',
#     'UnitId': 220,
#     'RoleDenominationId': 312,
#     'UnitName': 'Invalidenversicherungsstelle',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '0,1',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'sektionschef Zentrale Dienste',
#   'UnitsDisplay': 'GSD - Kantonale Sozialversicherungsanstalt',
#   'UnitsExports': 'Invalidenversicherungsstelle',
#   'UnitsFullNameExports': 'GSD - Kantonale Sozialversicherungsanstalt'},
#  {'DisplayName': 'Aebischer Maryse',
#   'Email': '',
#   'FirstName': 'Maryse',
#   'Id': 755,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 29 68',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '0,1',
#   'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#     'Email': '',
#     'Id': 318,
#     'PhoneNumber': '+41 26 305 29 68',
#     'RoleName': 'Dienstchefin',
#     'TitleName': None,
#     'UnitFullName': 'GSD - Sozialvorsorgeamt',
#     'UnitId': 40,
#     'RoleDenominationId': 339,
#     'UnitName': 'Sozialvorsorgeamt',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '0,1',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Dienstchefin',
#   'UnitsDisplay': 'GSD - Sozialvorsorgeamt',
#   'UnitsExports': 'Sozialvorsorgeamt',
#   'UnitsFullNameExports': 'GSD - Sozialvorsorgeamt'},
#  {'DisplayName': 'Aebischer Mélody',
#   'Email': 'melody.aebischer@fr.ch',
#   'FirstName': 'Mélody',
#   'Id': 4438,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 55 09',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'melody.aebischer@fr.ch',
#     'Id': 4718,
#     'PhoneNumber': '+41 26 305 55 09',
#     'RoleName': 'HR-Fachfrau',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#     'UnitId': 606,
#     'RoleDenominationId': 1271,
#     'UnitName': 'Verwaltung',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'HR-Fachfrau',
#   'UnitsDisplay': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#   'UnitsExports': 'Verwaltung',
#   'UnitsFullNameExports': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg'},
#  {'DisplayName': 'Aebischer Nicolas',
#   'Email': 'nicolas.aebischer@ocms-fribourg.ch',
#   'FirstName': 'Nicolas',
#   'Id': 1035,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 13 90',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'nicolas.aebischer@ocms-fribourg.ch',
#     'Id': 142,
#     'PhoneNumber': '+41 26 305 13 90',
#     'RoleName': 'Direktionsadjunkt',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Kantonale Lehrmittelverwaltung',
#     'UnitId': 50,
#     'RoleDenominationId': 7,
#     'UnitName': 'Kantonale Lehrmittelverwaltung',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Direktionsadjunkt',
#   'UnitsDisplay': 'EKSD - Kantonale Lehrmittelverwaltung',
#   'UnitsExports': 'Kantonale Lehrmittelverwaltung',
#   'UnitsFullNameExports': 'EKSD - Kantonale Lehrmittelverwaltung'},
#  {'DisplayName': 'Aebischer Nicolas',
#   'Email': 'nicolas.aebischer@fr.ch',
#   'FirstName': 'Nicolas',
#   'Id': 1401,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 37 60',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Raumplanungs-, Umwelt- und Baudirektion',
#     'Email': 'nicolas.aebischer@fr.ch',
#     'Id': 1843,
#     'PhoneNumber': '+41 26 305 37 60',
#     'RoleName': 'Sektorchef Wasserkontrollen und Chemikalien',
#     'TitleName': None,
#     'UnitFullName': 'RUBD - Amt für Umwelt',
#     'UnitId': 241,
#     'RoleDenominationId': 1874,
#     'UnitName': 'Sektion Labor und Stoffe',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Sektorchef Wasserkontrollen und Chemikalien',
#   'UnitsDisplay': 'RUBD - Amt für Umwelt',
#   'UnitsExports': 'Sektion Labor und Stoffe',
#   'UnitsFullNameExports': 'RUBD - Amt für Umwelt'},
#  {'DisplayName': 'Aebischer-Aeby Elisabeth',
#   'Email': 'aebischerel@edufr.ch',
#   'FirstName': 'Elisabeth',
#   'Id': 3119,
#   'LastName': 'Aebischer-Aeby',
#   'PhoneNumber': '+41 26 305 79 14',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'aebischerel@edufr.ch',
#     'Id': 3758,
#     'PhoneNumber': '+41 26 305 79 14',
#     'RoleName': 'Vorsteherin',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für Unterricht der Sekundarstufe 2',
#     'UnitId': 274,
#     'RoleDenominationId': 1005,
#     'UnitName': 'Kollegium Gambach',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Vorsteherin',
#   'UnitsDisplay': 'EKSD - Amt für Unterricht der Sekundarstufe 2',
#   'UnitsExports': 'Kollegium Gambach',
#   'UnitsFullNameExports': 'EKSD - Amt für Unterricht der Sekundarstufe 2'},
#  {'DisplayName': 'Aebischer-Piller Christa',
#   'Email': 'christa.aebischer@fr.ch',
#   'FirstName': 'Christa',
#   'Id': 895,
#   'LastName': 'Aebischer-Piller',
#   'PhoneNumber': '+41 26 305 40 88',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'christa.aebischer@fr.ch',
#     'Id': 2030,
#     'PhoneNumber': '+41 26 305 40 88',
#     'RoleName': 'Pädagogische Beraterin: Sprachförderung Eingangsstufe',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht',
#     'UnitId': 485,
#     'RoleDenominationId': 445,
#     'UnitName': 'Pädagogische Mitarbeit',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None},
#    {'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'christa.aebischer@fr.ch',
#     'Id': 1763,
#     'PhoneNumber': '+41 26 305 40 88',
#     'RoleName': 'Inspektorin',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht',
#     'UnitId': 405,
#     'RoleDenominationId': 839,
#     'UnitName': 'Inspektorat für den deutschsprachigen obligatorischen Unterricht, Tafers',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Pädagogische Beraterin: Sprachförderung Eingangsstufe, Inspektorin',
#   'UnitsDisplay': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht, EKSD - Amt für deutschsprachigen obligatorischen Unterricht',
#   'UnitsExports': 'Pädagogische Mitarbeit, Inspektorat für den deutschsprachigen obligatorischen Unterricht, Tafers',
#   'UnitsFullNameExports': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht, EKSD - Amt für deutschsprachigen obligatorischen Unterricht'},
#  {'DisplayName': 'Aeby Annabelle',
#   'Email': '',
#   'FirstName': 'Annabelle',
#   'Id': 1853,
#   'LastName': 'Aeby',
#   'PhoneNumber': '+41 26 305 79 89',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#     'Email': '',
#     'Id': 1160,
#     'PhoneNumber': '+41 26 305 79 89',
#     'RoleName': 'Pflegefachfrau',
#     'TitleName': None,
#     'UnitFullName': 'GSD - Kantonsarztamt',
#     'UnitId': 481,
#     'RoleDenominationId': 778,
#     'UnitName': 'Sektor Pflege',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Pflegefachfrau',
#   'UnitsDisplay': 'GSD - Kantonsarztamt',
#   'UnitsExports': 'Sektor Pflege',
#   'UnitsFullNameExports': 'GSD - Kantonsarztamt'},
#  {'DisplayName': 'Aeby Frédéric',
#   'Email': '',
#   'FirstName': 'Frédéric',
#   'Id': 6508,
#   'LastName': 'Aeby',
#   'PhoneNumber': '+41 26 305 40 85',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1536876000000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': '',
#     'Id': 6867,
#     'PhoneNumber': '+41 26 305 40 85',
#     'RoleName': 'Pädagogischer Mitarbeiter',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht',
#     'UnitId': 485,
#     'RoleDenominationId': 381,
#     'UnitName': 'Pädagogische Mitarbeit',
#     'Position': 7,
#     'PublicationStart': '/Date(1536876000000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Pädagogischer Mitarbeiter',
#   'UnitsDisplay': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht',
#   'UnitsExports': 'Pädagogische Mitarbeit',
#   'UnitsFullNameExports': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht'},
#  {'DisplayName': 'Aeby Pascal',
#   'Email': 'pascal.aeby@fr.ch',
#   'FirstName': 'Pascal',
#   'Id': 1205,
#   'LastName': 'Aeby',
#   'PhoneNumber': '+41 26 305 31 03',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Finanzdirektion',
#     'Email': 'pascal.aeby@fr.ch',
#     'Id': 776,
#     'PhoneNumber': '+41 26 305 31 03',
#     'RoleName': 'Generalsekretär',
#     'TitleName': None,
#     'UnitFullName': 'FIND - Generalsekretariat',
#     'UnitId': 16,
#     'RoleDenominationId': 1218,
#     'UnitName': 'Generalsekretariat',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Generalsekretär',
#   'UnitsDisplay': 'FIND - Generalsekretariat',
#   'UnitsExports': 'Generalsekretariat',
#   'UnitsFullNameExports': 'FIND - Generalsekretariat'},
#  {'DisplayName': 'Aeby Pierre',
#   'Email': 'pierre.aeby@fr.ch',
#   'FirstName': 'Pierre',
#   'Id': 1106,
#   'LastName': 'Aeby',
#   'PhoneNumber': '+41 26 305 58 62',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '0,1',
#   'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'pierre.aeby@fr.ch',
#     'Id': 3874,
#     'PhoneNumber': '+41 26 305 58 62',
#     'RoleName': 'Verantwortlicher für Pflanzenbau',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#     'UnitId': 800,
#     'RoleDenominationId': 1154,
#     'UnitName': 'Pflanzenbau (PB)',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '0,1',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Verantwortlicher für Pflanzenbau',
#   'UnitsDisplay': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#   'UnitsExports': 'Pflanzenbau (PB)',
#   'UnitsFullNameExports': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg'},
#  {'DisplayName': 'Aeby-Barrat Eléonore',
#   'Email': 'eleonore.aeby-barrat@fr.oai.ch',
#   'FirstName': 'Eléonore',
#   'Id': 1895,
#   'LastName': 'Aeby-Barrat',
#   'PhoneNumber': '+41 26 305 52 12',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(1533247200000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#     'Email': 'eleonore.aeby-barrat@fr.oai.ch',
#     'Id': 2042,
#     'PhoneNumber': '+41 26 305 52 12',
#     'RoleName': 'Sektionschefin Rechtsdienst',
#     'TitleName': None,
#     'UnitFullName': 'GSD - Kantonale Sozialversicherungsanstalt',
#     'UnitId': 220,
#     'RoleDenominationId': 1788,
#     'UnitName': 'Invalidenversicherungsstelle',
#     'Position': 0,
#     'PublicationStart': '/Date(1533247200000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Sektionschefin Rechtsdienst',
#   'UnitsDisplay': 'GSD - Kantonale Sozialversicherungsanstalt',
#   'UnitsExports': 'Invalidenversicherungsstelle',
#   'UnitsFullNameExports': 'GSD - Kantonale Sozialversicherungsanstalt'},
#  {'DisplayName': 'Aellen-Rey Fabienne',
#   'Email': 'fabienne.aellen-rey@fr.ch',
#   'FirstName': 'Fabienne',
#   'Id': 1767,
#   'LastName': 'Aellen-Rey',
#   'PhoneNumber': '+41 26 305 22 68',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'fabienne.aellen-rey@fr.ch',
#     'Id': 1511,
#     'PhoneNumber': '+41 26 305 22 68',
#     'RoleName': 'Verwaltungssachbearbeiterin',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Amt für Landwirtschaft',
#     'UnitId': 393,
#     'RoleDenominationId': 424,
#     'UnitName': 'Allgemeine Dienste',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Verwaltungssachbearbeiterin',
#   'UnitsDisplay': 'ILFD - Amt für Landwirtschaft',
#   'UnitsExports': 'Allgemeine Dienste',
#   'UnitsFullNameExports': 'ILFD - Amt für Landwirtschaft'},
#  {'DisplayName': 'Aerne Myriam',
#   'Email': 'Myriam.Aerne@fr.ch',
#   'FirstName': 'Myriam',
#   'Id': 6987,
#   'LastName': 'Aerne',
#   'PhoneNumber': '',
#   'PublicationEnd': '/Date(4094143200000)/',
#   'PublicationStart': '/Date(1569448800000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'Myriam.Aerne@fr.ch',
#     'Id': 7386,
#     'PhoneNumber': None,
#     'RoleName': 'Verantwortliche für Buchbinderei und Konservierung',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für Kultur',
#     'UnitId': 163,
#     'RoleDenominationId': 1917,
#     'UnitName': 'Kantons- und Universitätsbibliothek',
#     'Position': 0,
#     'PublicationStart': '/Date(1569448800000)/',
#     'PublicationEnd': '/Date(4094143200000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Verantwortliche für Buchbinderei und Konservierung',
#   'UnitsDisplay': 'EKSD - Amt für Kultur',
#   'UnitsExports': 'Kantons- und Universitätsbibliothek',
#   'UnitsFullNameExports': 'EKSD - Amt für Kultur'},
#  {'DisplayName': 'Aeschlimann David',
#   'Email': 'david.aeschlimann.sagri@fr.ch',
#   'FirstName': 'David',
#   'Id': 2205,
#   'LastName': 'Aeschlimann',
#   'PhoneNumber': '+41 26 305 23 03',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'david.aeschlimann.sagri@fr.ch',
#     'Id': 6587,
#     'PhoneNumber': '+41 26 305 23 03',
#     'RoleName': 'Regionalverantwortlicher Unterer Saanebezirk',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Amt für Landwirtschaft',
#     'UnitId': 395,
#     'RoleDenominationId': 1725,
#     'UnitName': 'Direktzahlungen',
#     'Position': 2,
#     'PublicationStart': '/Date(1517439600000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None},
#    {'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'david.aeschlimann.sagri@fr.ch',
#     'Id': 2048,
#     'PhoneNumber': '+41 26 305 23 03',
#     'RoleName': 'Sektionschef',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Amt für Landwirtschaft',
#     'UnitId': 393,
#     'RoleDenominationId': 259,
#     'UnitName': 'Allgemeine Dienste',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None},
#    {'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'david.aeschlimann.sagri@fr.ch',
#     'Id': 2237,
#     'PhoneNumber': '+41 26 305 23 03',
#     'RoleName': 'Wissenschaftlicher Berater',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Amt für Landwirtschaft',
#     'UnitId': 397,
#     'RoleDenominationId': 488,
#     'UnitName': 'Produkteförderung, Viehzucht und Weinbau',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Regionalverantwortlicher Unterer Saanebezirk, Sektionschef, Wissenschaftlicher Berater',
#   'UnitsDisplay': 'ILFD - Amt für Landwirtschaft, ILFD - Amt für Landwirtschaft, ILFD - Amt für Landwirtschaft',
#   'UnitsExports': 'Direktzahlungen, Allgemeine Dienste, Produkteförderung, Viehzucht und Weinbau',
#   'UnitsFullNameExports': 'ILFD - Amt für Landwirtschaft, ILFD - Amt für Landwirtschaft, ILFD - Amt für Landwirtschaft'},
#  {'DisplayName': 'Agustoni Clara',
#   'Email': 'clara.agustoni@fr.ch',
#   'FirstName': 'Clara',
#   'Id': 1077,
#   'LastName': 'Agustoni',
#   'PhoneNumber': '+41 26 667 97 96',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'clara.agustoni@fr.ch',
#     'Id': 1924,
#     'PhoneNumber': '+41 26 667 97 96',
#     'RoleName': 'Kon\xadser\xadva\xadto\xadrin',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für Archäologie',
#     'UnitId': 364,
#     'RoleDenominationId': 1381,
#     'UnitName': 'Musée romain de Vallon',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Kon\xadser\xadva\xadto\xadrin',
#   'UnitsDisplay': 'EKSD - Amt für Archäologie',
#   'UnitsExports': 'Musée romain de Vallon',
#   'UnitsFullNameExports': 'EKSD - Amt für Archäologie'},
#  {'DisplayName': 'Ajeti Ismail',
#   'Email': 'Ismail.Ajeti@fr.ch',
#   'FirstName': 'Ismail',
#   'Id': 3416,
#   'LastName': 'Ajeti',
#   'PhoneNumber': '+41 26 305 35 55',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Finanzdirektion',
#     'Email': 'Ismail.Ajeti@fr.ch',
#     'Id': 970,
#     'PhoneNumber': '+41 26 305 35 55',
#     'RoleName': 'Verwaltungsadjunkt',
#     'TitleName': None,
#     'UnitFullName': 'FIND - Amt für Vermessung und Geomatik',
#     'UnitId': 46,
#     'RoleDenominationId': 8,
#     'UnitName': 'Amt für Vermessung und Geomatik',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Verwaltungsadjunkt',
#   'UnitsDisplay': 'FIND - Amt für Vermessung und Geomatik',
#   'UnitsExports': 'Amt für Vermessung und Geomatik',
#   'UnitsFullNameExports': 'FIND - Amt für Vermessung und Geomatik'},
#  {'DisplayName': 'Allemann Aude',
#   'Email': 'aude.allemann@fr.ch',
#   'FirstName': 'Aude',
#   'Id': 5101,
#   'LastName': 'Allemann',
#   'PhoneNumber': '+41 26 305 73 66',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(1513897200000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'aude.allemann@fr.ch',
#     'Id': 5427,
#     'PhoneNumber': '+41 26 305 73 66',
#     'RoleName': 'Coordinatrice',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#     'UnitId': 384,
#     'RoleDenominationId': 1689,
#     'UnitName': 'Koordination für Schüleraustausch des Kantons Freiburg',
#     'Position': 0,
#     'PublicationStart': '/Date(1513897200000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Coordinatrice',
#   'UnitsDisplay': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#   'UnitsExports': 'Koordination für Schüleraustausch des Kantons Freiburg',
#   'UnitsFullNameExports': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht'},
#  {'DisplayName': 'Allemann Aude',
#   'Email': 'aude.allemann@fr.ch',
#   'FirstName': 'Aude',
#   'Id': 5102,
#   'LastName': 'Allemann',
#   'PhoneNumber': '+41 26 305 73 66',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(1513897200000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'aude.allemann@fr.ch',
#     'Id': 5428,
#     'PhoneNumber': '+41 26 305 73 66',
#     'RoleName': 'Coordinatrice',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht',
#     'UnitId': 382,
#     'RoleDenominationId': 1690,
#     'UnitName': 'Koordination für Schüleraustausch des Kantons Freiburg',
#     'Position': 0,
#     'PublicationStart': '/Date(1513897200000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Coordinatrice',
#   'UnitsDisplay': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht',
#   'UnitsExports': 'Koordination für Schüleraustausch des Kantons Freiburg',
#   'UnitsFullNameExports': 'EKSD - Amt für deutschsprachigen obligatorischen Unterricht'},
#  {'DisplayName': 'Allemann Aude',
#   'Email': 'aude.allemann@fr.ch',
#   'FirstName': 'Aude',
#   'Id': 6885,
#   'LastName': 'Allemann',
#   'PhoneNumber': '+41 26 305 73 66',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'aude.allemann@fr.ch',
#     'Id': 7282,
#     'PhoneNumber': '+41 26 305 73 66',
#     'RoleName': 'Sprachaustausche',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#     'UnitId': 473,
#     'RoleDenominationId': 1895,
#     'UnitName': 'Pädagogische Berater/innen',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Sprachaustausche',
#   'UnitsDisplay': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#   'UnitsExports': 'Pädagogische Berater/innen',
#   'UnitsFullNameExports': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht'},
#  {'DisplayName': 'Allemann Vincent',
#   'Email': 'vincent.allemann@fr.ch',
#   'FirstName': 'Vincent',
#   'Id': 3726,
#   'LastName': 'Allemann',
#   'PhoneNumber': '+41 26 305 22 61',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'vincent.allemann@fr.ch',
#     'Id': 2182,
#     'PhoneNumber': '+41 26 305 22 61',
#     'RoleName': 'Regionalversantwortlicher Gruyère und Veveyse Süd – Sömmerungsgebiet französischsprachiger Teil',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Amt für Landwirtschaft',
#     'UnitId': 395,
#     'RoleDenominationId': 1736,
#     'UnitName': 'Direktzahlungen',
#     'Position': 3,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Regionalversantwortlicher Gruyère und Veveyse Süd – Sömmerungsgebiet französischsprachiger Teil',
#   'UnitsDisplay': 'ILFD - Amt für Landwirtschaft',
#   'UnitsExports': 'Direktzahlungen',
#   'UnitsFullNameExports': 'ILFD - Amt für Landwirtschaft'},
#  {'DisplayName': 'Amschwand Fabian Max Theodor',
#   'Email': 'fabian.amschwand@unifr.ch',
#   'FirstName': 'Fabian Max Theodor',
#   'Id': 3887,
#   'LastName': 'Amschwand',
#   'PhoneNumber': '+41 26 300 70 04',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1550012400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'fabian.amschwand@unifr.ch',
#     'Id': 2412,
#     'PhoneNumber': '+41 26 300 70 04',
#     'RoleName': 'Generalsekretär',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Universität',
#     'UnitId': 242,
#     'RoleDenominationId': 1218,
#     'UnitName': 'Rektorat',
#     'Position': 2,
#     'PublicationStart': '/Date(1550012400000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Generalsekretär',
#   'UnitsDisplay': 'EKSD - Universität',
#   'UnitsExports': 'Rektorat',
#   'UnitsFullNameExports': 'EKSD - Universität'},
#  {'DisplayName': 'Andenmatten Patrick',
#   'Email': 'patrick.andenmatten@fr.ch',
#   'FirstName': 'Patrick',
#   'Id': 1758,
#   'LastName': 'Andenmatten',
#   'PhoneNumber': '+41 26 305 52 75',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#     'Email': 'patrick.andenmatten@fr.ch',
#     'Id': 1566,
#     'PhoneNumber': '+41 26 305 52 75',
#     'RoleName': 'Wirtschaftswissenschaftlicher Berater, Chef der Finanzabteilung',
#     'TitleName': None,
#     'UnitFullName': 'GSD - Kantonale Sozialversicherungsanstalt',
#     'UnitId': 219,
#     'RoleDenominationId': 1889,
#     'UnitName': 'Kantonale Ausgleichskasse AH/IV/EO',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Wirtschaftswissenschaftlicher Berater, Chef der Finanzabteilung',
#   'UnitsDisplay': 'GSD - Kantonale Sozialversicherungsanstalt',
#   'UnitsExports': 'Kantonale Ausgleichskasse AH/IV/EO',
#   'UnitsFullNameExports': 'GSD - Kantonale Sozialversicherungsanstalt'},
#  {'DisplayName': 'Andrey Colette',
#   'Email': 'colette.andrey@fr.ch',
#   'FirstName': 'Colette',
#   'Id': 626,
#   'LastName': 'Andrey',
#   'PhoneNumber': '+41 26 305 58 53',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'colette.andrey@fr.ch',
#     'Id': 3893,
#     'PhoneNumber': '+41 26 305 58 53',
#     'RoleName': 'Hauswirtschaftliche Beraterin',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#     'UnitId': 802,
#     'RoleDenominationId': 1623,
#     'UnitName': 'Weiterbildung Hauswirtschaft',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Hauswirtschaftliche Beraterin',
#   'UnitsDisplay': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#   'UnitsExports': 'Weiterbildung Hauswirtschaft',
#   'UnitsFullNameExports': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg'},
#  {'DisplayName': 'Andrey Karin',
#   'Email': '',
#   'FirstName': 'Karin',
#   'Id': 1869,
#   'LastName': 'Andrey',
#   'PhoneNumber': '+41 26 305 22 04',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': '',
#     'Id': 250,
#     'PhoneNumber': '+41 26 305 22 04',
#     'RoleName': 'Übersetzerin',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Generalsekretariat',
#     'UnitId': 92,
#     'RoleDenominationId': 1313,
#     'UnitName': 'Generalsekretariat',
#     'Position': 12,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Übersetzerin',
#   'UnitsDisplay': 'ILFD - Generalsekretariat',
#   'UnitsExports': 'Generalsekretariat',
#   'UnitsFullNameExports': 'ILFD - Generalsekretariat'},
#  {'DisplayName': 'Andrey Nicole',
#   'Email': 'nicole.andrey@fr.ch',
#   'FirstName': 'Nicole',
#   'Id': 3543,
#   'LastName': 'Andrey',
#   'PhoneNumber': '+41 26 305 23 43',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'nicole.andrey@fr.ch',
#     'Id': 3637,
#     'PhoneNumber': '+41 26 305 23 43',
#     'RoleName': 'Verwaltungssachbearbeiterin',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Amt für Wald und Natur',
#     'UnitId': 790,
#     'RoleDenominationId': 424,
#     'UnitName': 'Sektor Verwaltung und Finanzen',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Verwaltungssachbearbeiterin',
#   'UnitsDisplay': 'ILFD - Amt für Wald und Natur',
#   'UnitsExports': 'Sektor Verwaltung und Finanzen',
#   'UnitsFullNameExports': 'ILFD - Amt für Wald und Natur'},
#  {'DisplayName': 'Andrey Patrik',
#   'Email': 'patrik.andrey@fr.ch',
#   'FirstName': 'Patrik',
#   'Id': 6288,
#   'LastName': 'Andrey',
#   'PhoneNumber': '+41 26 304 16 21',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1519858800000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'patrik.andrey@fr.ch',
#     'Id': 6630,
#     'PhoneNumber': '+41 26 304 16 21',
#     'RoleName': 'Verwalter',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für Sport',
#     'UnitId': 974,
#     'RoleDenominationId': 1743,
#     'UnitName': 'Campus Schwarzsee',
#     'Position': 1,
#     'PublicationStart': '/Date(1519858800000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Verwalter',
#   'UnitsDisplay': 'EKSD - Amt für Sport',
#   'UnitsExports': 'Campus Schwarzsee',
#   'UnitsFullNameExports': 'EKSD - Amt für Sport'},
#  {'DisplayName': 'Andric Josip',
#   'Email': '',
#   'FirstName': 'Josip',
#   'Id': 6502,
#   'LastName': 'Andric',
#   'PhoneNumber': '+41 26 305 46 24',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(1535925600000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#     'Email': '',
#     'Id': 6860,
#     'PhoneNumber': '+41 26 305 46 24',
#     'RoleName': 'Wirtschaftswissenschaftler',
#     'TitleName': None,
#     'UnitFullName': 'GSD - Sozialvorsorgeamt',
#     'UnitId': 221,
#     'RoleDenominationId': 1804,
#     'UnitName': 'Sondereinrichtungen',
#     'Position': 0,
#     'PublicationStart': '/Date(1535925600000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Wirtschaftswissenschaftler',
#   'UnitsDisplay': 'GSD - Sozialvorsorgeamt',
#   'UnitsExports': 'Sondereinrichtungen',
#   'UnitsFullNameExports': 'GSD - Sozialvorsorgeamt'},
#  {'DisplayName': 'Angéloz Carole',
#   'Email': 'carole.angeloz@fr.ch',
#   'FirstName': 'Carole',
#   'Id': 1537,
#   'LastName': 'Angéloz',
#   'PhoneNumber': '+41 26 305 73 68',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'carole.angeloz@fr.ch',
#     'Id': 2113,
#     'PhoneNumber': '+41 26 305 73 68',
#     'RoleName': 'Schulinspektorin',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#     'UnitId': 366,
#     'RoleDenominationId': 1556,
#     'UnitName': 'Schulinspektorat',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Schulinspektorin',
#   'UnitsDisplay': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#   'UnitsExports': 'Schulinspektorat',
#   'UnitsFullNameExports': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht'},
#  {'DisplayName': 'Angéloz Cindy',
#   'Email': 'cindy.angeloz@fr.ch',
#   'FirstName': 'Cindy',
#   'Id': 6412,
#   'LastName': 'Angéloz',
#   'PhoneNumber': '+41 26 305 73 71',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'cindy.angeloz@fr.ch',
#     'Id': 6765,
#     'PhoneNumber': '+41 26 305 73 71',
#     'RoleName': 'Französisch 1. Zyklus',
#     'TitleName': None,
# ...
#   'UnitsExports': 'PS Bossonnens',
#   'UnitsFullNameExports': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht'},
#  {'DisplayName': 'Monney Corinne',
#   'Email': 'Monneyc03@edufr.ch',
#   'FirstName': 'Corinne',
#   'Id': 4266,
#   'LastName': 'Monney',
#   'PhoneNumber': '+41 26 305 25 27',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1451602800000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Volkswirtschaftsdirektion',
#     'Email': 'Monneyc03@edufr.ch',
#     'Id': 4530,
#     'PhoneNumber': '+41 26 305 25 27',
#     'RoleName': 'Sekretärin',
#     'TitleName': None,
#     'UnitFullName': 'VWD - Amt für Berufsbildung',
#     'UnitId': 126,
#     'RoleDenominationId': 1200,
#     'UnitName': 'Kaufmännische Berufsfachschule',
#     'Position': 0,
#     'PublicationStart': '/Date(1451602800000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Sekretärin',
#   'UnitsDisplay': 'VWD - Amt für Berufsbildung',
#   'UnitsExports': 'Kaufmännische Berufsfachschule',
#   'UnitsFullNameExports': 'VWD - Amt für Berufsbildung'},
#  {'DisplayName': 'Monney Jean-Blaise',
#   'Email': 'jean-blaise.monney@fr.ch',
#   'FirstName': 'Jean-Blaise',
#   'Id': 2142,
#   'LastName': 'Monney',
#   'PhoneNumber': '+41 26 305 23 43, +41 26 305 55 33',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'jean-blaise.monney@fr.ch',
#     'Id': 3643,
#     'PhoneNumber': '+41 26 305 23 43',
#     'RoleName': 'Bibliothekar',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Amt für Wald und Natur',
#     'UnitId': 790,
#     'RoleDenominationId': 1454,
#     'UnitName': 'Sektor Verwaltung und Finanzen',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None},
#    {'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'jean-blaise.monney@fr.ch',
#     'Id': 3216,
#     'PhoneNumber': '+41 26 305 55 33',
#     'RoleName': 'Bibliothekar',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#     'UnitId': 606,
#     'RoleDenominationId': 1454,
#     'UnitName': 'Verwaltung',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Bibliothekar, Bibliothekar',
#   'UnitsDisplay': 'ILFD - Amt für Wald und Natur, ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#   'UnitsExports': 'Sektor Verwaltung und Finanzen, Verwaltung',
#   'UnitsFullNameExports': 'ILFD - Amt für Wald und Natur, ILFD - Landwirtschaftliches Institut des Kantons Freiburg'},
#  {'DisplayName': 'Monney Jean-Marc',
#   'Email': 'jean-marc.monney@fr.ch',
#   'FirstName': 'Jean-Marc',
#   'Id': 490,
#   'LastName': 'Monney',
#   'PhoneNumber': '+41 26 305 38 79',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Raumplanungs-, Umwelt- und Baudirektion',
#     'Email': 'jean-marc.monney@fr.ch',
#     'Id': 2902,
#     'PhoneNumber': '+41 26 305 38 79',
#     'RoleName': 'Technischer Sachbearbeiter',
#     'TitleName': None,
#     'UnitFullName': 'RUBD - Tiefbauamt',
#     'UnitId': 704,
#     'RoleDenominationId': 406,
#     'UnitName': 'Überwachung und Planung von Kunstbauten',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Technischer Sachbearbeiter',
#   'UnitsDisplay': 'RUBD - Tiefbauamt',
#   'UnitsExports': 'Überwachung und Planung von Kunstbauten',
#   'UnitsFullNameExports': 'RUBD - Tiefbauamt'},
#  {'DisplayName': 'Monney Maria-Elena',
#   'Email': 'direction.ep.salesvaulruz@fr.educanet2.ch',
#   'FirstName': 'Maria-Elena',
#   'Id': 4090,
#   'LastName': 'Monney',
#   'PhoneNumber': '+41 26 913 04 10',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1441922400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'direction.ep.salesvaulruz@fr.educanet2.ch',
#     'Id': 4332,
#     'PhoneNumber': '+41 26 913 04 10',
#     'RoleName': 'Schulleiter-in',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#     'UnitId': 875,
#     'RoleDenominationId': 1428,
#     'UnitName': 'PS Sâles, Vaulruz',
#     'Position': 0,
#     'PublicationStart': '/Date(1441922400000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Schulleiter-in',
#   'UnitsDisplay': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#   'UnitsExports': 'PS Sâles, Vaulruz',
#   'UnitsFullNameExports': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht'},
#  {'DisplayName': 'Monney Pierre',
#   'Email': 'pierre.monney@fr.ch',
#   'FirstName': 'Pierre',
#   'Id': 1653,
#   'LastName': 'Monney',
#   'PhoneNumber': '+41 26 305 55 79',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '0,1',
#   'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'pierre.monney@fr.ch',
#     'Id': 3906,
#     'PhoneNumber': '+41 26 305 55 79',
#     'RoleName': 'Lehrer Allgemeinbildung',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#     'UnitId': 804,
#     'RoleDenominationId': 673,
#     'UnitName': 'Ausbildung Hauswirtschaft dual',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '0,1',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Lehrer Allgemeinbildung',
#   'UnitsDisplay': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#   'UnitsExports': 'Ausbildung Hauswirtschaft dual',
#   'UnitsFullNameExports': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg'},
#  {'DisplayName': 'Monney Regina',
#   'Email': 'regina.monney@fr.ch',
#   'FirstName': 'Regina',
#   'Id': 1777,
#   'LastName': 'Monney',
#   'PhoneNumber': '+41 26 305 23 43',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'regina.monney@fr.ch',
#     'Id': 3640,
#     'PhoneNumber': '+41 26 305 23 43',
#     'RoleName': 'Sekretärin',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Amt für Wald und Natur',
#     'UnitId': 790,
#     'RoleDenominationId': 1200,
#     'UnitName': 'Sektor Verwaltung und Finanzen',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Sekretärin',
#   'UnitsDisplay': 'ILFD - Amt für Wald und Natur',
#   'UnitsExports': 'Sektor Verwaltung und Finanzen',
#   'UnitsFullNameExports': 'ILFD - Amt für Wald und Natur'},
#  {'DisplayName': 'Monney Sandrine',
#   'Email': '',
#   'FirstName': 'Sandrine',
#   'Id': 2173,
#   'LastName': 'Monney',
#   'PhoneNumber': '+41 26 305 98 00',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#     'Email': '',
#     'Id': 1362,
#     'PhoneNumber': '+41 26 305 98 00',
#     'RoleName': 'Dentalassistentin',
#     'TitleName': None,
#     'UnitFullName': 'GSD - Schulzahnpflegedienst',
#     'UnitId': 304,
#     'RoleDenominationId': 146,
#     'UnitName': 'Zahnklinik Freiburg',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Dentalassistentin',
#   'UnitsDisplay': 'GSD - Schulzahnpflegedienst',
#   'UnitsExports': 'Zahnklinik Freiburg',
#   'UnitsFullNameExports': 'GSD - Schulzahnpflegedienst'},
#  {'DisplayName': 'Monnier Jacques',
#   'Email': 'jacques.monnier@fr.ch',
#   'FirstName': 'Jacques',
#   'Id': 1587,
#   'LastName': 'Monnier',
#   'PhoneNumber': '+41 26 305 82 42',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'jacques.monnier@fr.ch',
#     'Id': 1617,
#     'PhoneNumber': '+41 26 305 82 42',
#     'RoleName': 'Sektorchef Gallo-römisch',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für Archäologie',
#     'UnitId': 346,
#     'RoleDenominationId': 250,
#     'UnitName': 'Ausgrabungen, Forschungen und Publikationen',
#     'Position': 3,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Sektorchef Gallo-römisch',
#   'UnitsDisplay': 'EKSD - Amt für Archäologie',
#   'UnitsExports': 'Ausgrabungen, Forschungen und Publikationen',
#   'UnitsFullNameExports': 'EKSD - Amt für Archäologie'},
#  {'DisplayName': 'Monpays Christine',
#   'Email': 'direction.ep.granges-paccot@fr.educanet2.ch',
#   'FirstName': 'Christine',
#   'Id': 6419,
#   'LastName': 'Monpays',
#   'PhoneNumber': '+41 26 460 68 41',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1441922400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'direction.ep.granges-paccot@fr.educanet2.ch',
#     'Id': 6772,
#     'PhoneNumber': '+41 26 460 68 41',
#     'RoleName': 'Schulleiter-in',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#     'UnitId': 848,
#     'RoleDenominationId': 1428,
#     'UnitName': 'PS Granges-Paccot - La Sonnaz',
#     'Position': 0,
#     'PublicationStart': '/Date(1441922400000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Schulleiter-in',
#   'UnitsDisplay': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht',
#   'UnitsExports': 'PS Granges-Paccot - La Sonnaz',
#   'UnitsFullNameExports': 'EKSD - Amt für französischsprachigen obligatorischen Unterricht'},
#  {'DisplayName': 'Monterrubio Leu Cristina',
#   'Email': '',
#   'FirstName': 'Cristina',
#   'Id': 4418,
#   'LastName': 'Monterrubio Leu',
#   'PhoneNumber': '+41 26 305 79 92',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1463004000000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Gesundheit und Soziales',
#     'Email': '',
#     'Id': 4697,
#     'PhoneNumber': '+41 26 305 79 92',
#     'RoleName': 'Wissenschaftliche Mitarbeiterin',
#     'TitleName': None,
#     'UnitFullName': 'GSD - Kantonsarztamt',
#     'UnitId': 483,
#     'RoleDenominationId': 448,
#     'UnitName': 'Sektor Wissenschaftliche Mitarbeit',
#     'Position': 2,
#     'PublicationStart': '/Date(1463004000000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Wissenschaftliche Mitarbeiterin',
#   'UnitsDisplay': 'GSD - Kantonsarztamt',
#   'UnitsExports': 'Sektor Wissenschaftliche Mitarbeit',
#   'UnitsFullNameExports': 'GSD - Kantonsarztamt'},
#  {'DisplayName': 'Mooser Coumba',
#   'Email': 'coumba.mooser@fr.ch',
#   'FirstName': 'Coumba',
#   'Id': 6289,
#   'LastName': 'Mooser',
#   'PhoneNumber': '+41 26 304 16 27',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1519858800000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion für Erziehung, Kultur und Sport',
#     'Email': 'coumba.mooser@fr.ch',
#     'Id': 6631,
#     'PhoneNumber': '+41 26 304 16 27',
#     'RoleName': 'Verwaltungsangestellte',
#     'TitleName': None,
#     'UnitFullName': 'EKSD - Amt für Sport',
#     'UnitId': 974,
#     'RoleDenominationId': 1593,
#     'UnitName': 'Campus Schwarzsee',
#     'Position': 2,
#     'PublicationStart': '/Date(1519858800000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Verwaltungsangestellte',
#   'UnitsDisplay': 'EKSD - Amt für Sport',
#   'UnitsExports': 'Campus Schwarzsee',
#   'UnitsFullNameExports': 'EKSD - Amt für Sport'},
#  {'DisplayName': 'Morand Monique',
#   'Email': 'Monique.Morand@fr.ch',
#   'FirstName': 'Monique',
#   'Id': 829,
#   'LastName': 'Morand',
#   'PhoneNumber': '+41 26 305 36 41',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Raumplanungs-, Umwelt- und Baudirektion',
#     'Email': 'Monique.Morand@fr.ch',
#     'Id': 1626,
#     'PhoneNumber': '+41 26 305 36 41',
#     'RoleName': 'Sektionschefin',
#     'TitleName': None,
#     'UnitFullName': 'RUBD - Tiefbauamt',
#     'UnitId': 210,
#     'RoleDenominationId': 335,
#     'UnitName': 'Verwaltung (Verw)',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None},
#    {'DirectionName': 'Raumplanungs-, Umwelt- und Baudirektion',
#     'Email': 'Monique.Morand@fr.ch',
#     'Id': 2469,
#     'PhoneNumber': '+41 26 305 36 41',
#     'RoleName': 'Sektionschefin',
#     'TitleName': None,
#     'UnitFullName': 'RUBD - Tiefbauamt',
#     'UnitId': 690,
#     'RoleDenominationId': 335,
#     'UnitName': 'Personal',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Sektionschefin, Sektionschefin',
#   'UnitsDisplay': 'RUBD - Tiefbauamt, RUBD - Tiefbauamt',
#   'UnitsExports': 'Verwaltung (Verw), Personal',
#   'UnitsFullNameExports': 'RUBD - Tiefbauamt, RUBD - Tiefbauamt'},
#  {'DisplayName': 'Morel Bernard',
#   'Email': 'bernard.morel@fr.ch',
#   'FirstName': 'Bernard',
#   'Id': 1811,
#   'LastName': 'Morel',
#   'PhoneNumber': '+41 26 305 55 10',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direktion der Institutionen und der Land- und Forstwirtschaft',
#     'Email': 'bernard.morel@fr.ch',
#     'Id': 2552,
#     'PhoneNumber': '+41 26 305 55 10',
#     'RoleName': 'Chefbuchhalter',
#     'TitleName': None,
#     'UnitFullName': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#     'UnitId': 514,
#     'RoleDenominationId': 194,
#     'UnitName': 'Buchhaltung',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Chefbuchhalter',
#   'UnitsDisplay': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg',
#   'UnitsExports': 'Buchhaltung',
#   'UnitsFullNameExports': 'ILFD - Landwirtschaftliches Institut des Kantons Freiburg'},
#  ...]

# %%
# Zugreifen auf das zweite Element von 'Data'
response_as_json['Data'][1]
# Out:
# {'DisplayName': 'Abeztout Abderrahim',
#  'Email': 'abderrahim.abeztout@fr.ch',
#  'FirstName': 'Abderrahim',
#  'Id': 4423,
#  'LastName': 'Abeztout',
#  'PhoneNumber': '+41 26 305 37 97',
#  'PublicationEnd': None,
#  'PublicationStart': '/Date(1463608800000)/',
#  'PublicationTarget': '1,0',
#  'Roles': [{'DirectionName': 'Raumplanungs-, Umwelt- und Baudirektion',
#    'Email': 'abderrahim.abeztout@fr.ch',
#    'Id': 4703,
#    'PhoneNumber': '+41 26 305 37 97',
#    'RoleName': 'Architektin',
#    'TitleName': None,
#    'UnitFullName': 'RUBD - Hochbauamt',
#    'UnitId': 235,
#    'RoleDenominationId': 121,
#    'UnitName': 'Technische Abteilung',
#    'Position': 0,
#    'PublicationStart': '/Date(1463608800000)/',
#    'PublicationEnd': None,
#    'PublicationTarget': '1,0',
#    'WebDispatchingType': 1,
#    'UnitFullPath': None,
#    'UnitPath': None}],
#  'RolesDisplay': 'Architektin',
#  'UnitsDisplay': 'RUBD - Hochbauamt',
#  'UnitsExports': 'Technische Abteilung',
#  'UnitsFullNameExports': 'RUBD - Hochbauamt'}

# %% [markdown]
# So schön. Aus dem baue ich jetzt eine For-Loop mit dictionary.

# %%
# For Loop


verzeichnis = []

for person in response_as_json['Data']:
    thisperson = {}
    thisperson['1 Name'] = person['DisplayName'] if not person['DisplayName'] is None else ''
    thisperson['2 ID'] = person['Id'] if not person['Id'] is None else ''
    thisperson['3 Email'] = person['Email'] if not person['Email'] is None else ''
    thisperson['4 Direktion'] = person['Roles'][0]['DirectionName'] if not person['Roles'] is None and len(person['Roles']) > 0 else ''
    thisperson['5 Sektion'] = person['UnitsDisplay'] if not person['UnitsDisplay'] is None else ''
    thisperson['6 Abteilung'] = person['UnitsExports'] if not person['UnitsExports'] is None else ''
    thisperson['7 Funktion'] = person['RolesDisplay'] if not person['RolesDisplay'] is None else ''
    
    verzeichnis.append(thisperson)
    
pd.DataFrame(verzeichnis)
# Out:
#                          1 Name  2 ID  \
# 0                       --- ---    96
# 1           Abeztout Abderrahim  4423
# 2          Ackermann Christophe  1544
# 3                 Ackermann Urs  3557
# 4                   Adam Samuel  2628
# 5              Aebischer Adrian  1289
# 6           Aebischer Christoph  1580
# 7             Aebischer Fernand    36
# 8             Aebischer Florent  3328
# 9           Aebischer Jean-Marc  1038
# 10          Aebischer Jean-Marc  4664
# 11         Aebischer Jean-Marie   609
# 12             Aebischer Maryse   755
# 13             Aebischer Mélody  4438
# 14            Aebischer Nicolas  1035
# 15            Aebischer Nicolas  1401
# 16     Aebischer-Aeby Elisabeth  3119
# 17     Aebischer-Piller Christa   895
# 18               Aeby Annabelle  1853
# 19                Aeby Frédéric  6508
# 20                  Aeby Pascal  1205
# 21                  Aeby Pierre  1106
# 22         Aeby-Barrat Eléonore  1895
# 23          Aellen-Rey Fabienne  1767
# 24                 Aerne Myriam  6987
# 25            Aeschlimann David  2205
# 26               Agustoni Clara  1077
# 27                 Ajeti Ismail  3416
# 28                Allemann Aude  5101
# 29                Allemann Aude  5102
# ...                         ...   ...
# 1563            Wyrsch Isabelle  1092
# 1564              Wyss Marielle  4900
# 1565                Wyss Nicole  4044
# 1566               Wyssa Andres  3009
# 1567               Yerly Carina  3280
# 1568              Yerly Laurent  3687
# 1569              Yerly Mélanie  4063
# 1570               Yerly Noémie  6357
# 1571                 YERLY Yves  3407
# 1572      Yerly Vienne Caroline  2155
# 1573            Zablot Philippe   681
# 1574      Zanetti Jean-François  1379
# 1575               Zaugg Claude   396
# 1576               ZAUGG Fabien  3388
# 1577                  Zaugg Urs  6297
# 1578              Zbinden Anita  2104
# 1579            Zbinden Claudia  3737
# 1580             Zbinden Martin  3513
# 1581    Zbinden-Barras Marianne  1085
# 1582  Zbinden-Thalmann Brigitte   985
# 1583        Zehnder-Jörg Silvia  1768
# 1584              Zekjiri lekha  6263
# 1585               Zollet Peter  3517
# 1586            Zosso Alexandre  2076
# 1587           Zosso Bernadette  3682
# 1588               Zosso Daniel  4929
# 1589                 Zosso Hugo   535
# 1590             Zürcher Janine  2479
# 1591               Zurfluh Marc  6966
# 1592            Zurkinden Simon  6947
#
#                                           3 Email  \
# 0
# 1                       abderrahim.abeztout@fr.ch
# 2                      christophe.ackermann@fr.ch
# 3                             urs.ackermann@fr.ch
# 4
# 5                          adrian.aebischer@fr.ch
# 6
# 7                                   Non renseigné
# 8                         florent.aebischer@fr.ch
# 9
# 10                      jean-marc.aebischer@fr.ch
# 11                 jean-marie.aebischer@fr.oai.ch
# 12
# 13                         melody.aebischer@fr.ch
# 14             nicolas.aebischer@ocms-fribourg.ch
# 15                        nicolas.aebischer@fr.ch
# 16                           aebischerel@edufr.ch
# 17                        christa.aebischer@fr.ch
# 18
# 19
# 20                              pascal.aeby@fr.ch
# 21                              pierre.aeby@fr.ch
# 22                 eleonore.aeby-barrat@fr.oai.ch
# 23                      fabienne.aellen-rey@fr.ch
# 24                             Myriam.Aerne@fr.ch
# 25                  david.aeschlimann.sagri@fr.ch
# 26                           clara.agustoni@fr.ch
# 27                             Ismail.Ajeti@fr.ch
# 28                            aude.allemann@fr.ch
# 29                            aude.allemann@fr.ch
# ...                                           ...
# 1563                             wyrschi@edufr.ch
# 1564
# 1565     direction.ep.regionmorat@fr.educanet2.ch
# 1566                                Non renseigné
# 1567
# 1568                          laurent.yerly@fr.ch
# 1569  direction.ep.flon-st-matin@fr.educanet2.ch
# 1570                           noemie.yerly@fr.ch
# 1571
# 1572                         caroline.yerly@fr.ch
# 1573
# 1574
# 1575                           claude.zaugg@fr.ch
# 1576
# 1577                              urs.zaugg@fr.ch
# 1578
# 1579                            zbindenc@edufr.ch
# 1580
# 1581
# 1582                       brigitte.zbinden@fr.ch
# 1583                   silvia.zehnder-joerg@fr.ch
# 1584
# 1585                        peter.zollet@edufr.ch
# 1586                  , alexandre.zosso.avs@fr.ch
# 1587                    bernadette.zosso@edufr.ch
# 1588                           daniel.zosso@fr.ch
# 1589                             hugo.zosso@fr.ch
# 1590                        janine.zuercher@fr.ch
# 1591                          marc.zurfluh@cpi.ch
# 1592                        simon.zurkinden@fr.ch
#
#                                             4 Direktion  \
# 0                                         Staatskanzlei
# 1               Raumplanungs-, Umwelt- und Baudirektion
# 2                                       Finanzdirektion
# 3     Direktion der Institutionen und der Land- und ...
# 4                 Direktion für Gesundheit und Soziales
# 5     Direktion der Institutionen und der Land- und ...
# 6                             Volkswirtschaftsdirektion
# 7                                          Verschiedene
# 8                             Volkswirtschaftsdirektion
# 9             Direktion für Erziehung, Kultur und Sport
# 10            Direktion für Erziehung, Kultur und Sport
# 11                Direktion für Gesundheit und Soziales
# 12                Direktion für Gesundheit und Soziales
# 13    Direktion der Institutionen und der Land- und ...
# 14            Direktion für Erziehung, Kultur und Sport
# 15              Raumplanungs-, Umwelt- und Baudirektion
# 16            Direktion für Erziehung, Kultur und Sport
# 17            Direktion für Erziehung, Kultur und Sport
# 18                Direktion für Gesundheit und Soziales
# 19            Direktion für Erziehung, Kultur und Sport
# 20                                      Finanzdirektion
# 21    Direktion der Institutionen und der Land- und ...
# 22                Direktion für Gesundheit und Soziales
# 23    Direktion der Institutionen und der Land- und ...
# 24            Direktion für Erziehung, Kultur und Sport
# 25    Direktion der Institutionen und der Land- und ...
# 26            Direktion für Erziehung, Kultur und Sport
# 27                                      Finanzdirektion
# 28            Direktion für Erziehung, Kultur und Sport
# 29            Direktion für Erziehung, Kultur und Sport
# ...                                                 ...
# 1563          Direktion für Erziehung, Kultur und Sport
# 1564          Direktion für Erziehung, Kultur und Sport
# 1565          Direktion für Erziehung, Kultur und Sport
# 1566  Direktion der Institutionen und der Land- und ...
# 1567  Direktion der Institutionen und der Land- und ...
# 1568                                    Finanzdirektion
# 1569          Direktion für Erziehung, Kultur und Sport
# 1570                                    Finanzdirektion
# 1571                   Sicherheits- und Justizdirektion
# 1572  Direktion der Institutionen und der Land- und ...
# 1573          Direktion für Erziehung, Kultur und Sport
# 1574            Raumplanungs-, Umwelt- und Baudirektion
# 1575          Direktion für Erziehung, Kultur und Sport
# 1576                   Sicherheits- und Justizdirektion
# 1577  Direktion der Institutionen und der Land- und ...
# 1578                                      Staatskanzlei
# 1579                          Volkswirtschaftsdirektion
# 1580          Direktion für Erziehung, Kultur und Sport
# 1581              Direktion für Gesundheit und Soziales
# 1582  Direktion der Institutionen und der Land- und ...
# 1583          Direktion für Erziehung, Kultur und Sport
# 1584                          Volkswirtschaftsdirektion
# 1585                          Volkswirtschaftsdirektion
# 1586              Direktion für Gesundheit und Soziales
# 1587                          Volkswirtschaftsdirektion
# 1588            Raumplanungs-, Umwelt- und Baudirektion
# 1589  Direktion der Institutionen und der Land- und ...
# 1590            Raumplanungs-, Umwelt- und Baudirektion
# 1591                          Volkswirtschaftsdirektion
# 1592                                    Finanzdirektion
#
#                                               5 Sektion  \
# 0                                     SK - Staatsarchiv
# 1                                     RUBD - Hochbauamt
# 2                              FIND - Finanzinspektorat
# 3     ILFD - Amt für institutionelle Angelegenheiten...
# 4                                  GSD - Kantonsarztamt
# 5                         ILFD - Amt für Wald und Natur
# 6            VWD - Wirtschaftsförderung Kanton Freiburg
# 7          Vers - Sportvereinigung des Staates Freiburg
# 8                              VWD - Handelsregisteramt
# 9                                  EKSD - Amt für Sport
# 10    EKSD - Amt für französischsprachigen obligator...
# 11           GSD - Kantonale Sozialversicherungsanstalt
# 12                              GSD - Sozialvorsorgeamt
# 13    ILFD - Landwirtschaftliches Institut des Kanto...
# 14                EKSD - Kantonale Lehrmittelverwaltung
# 15                                RUBD - Amt für Umwelt
# 16        EKSD - Amt für Unterricht der Sekundarstufe 2
# 17    EKSD - Amt für deutschsprachigen obligatorisch...
# 18                                 GSD - Kantonsarztamt
# 19    EKSD - Amt für deutschsprachigen obligatorisch...
# 20                            FIND - Generalsekretariat
# 21    ILFD - Landwirtschaftliches Institut des Kanto...
# 22           GSD - Kantonale Sozialversicherungsanstalt
# 23                        ILFD - Amt für Landwirtschaft
# 24                                EKSD - Amt für Kultur
# 25    ILFD - Amt für Landwirtschaft, ILFD - Amt für ...
# 26                           EKSD - Amt für Archäologie
# 27               FIND - Amt für Vermessung und Geomatik
# 28    EKSD - Amt für französischsprachigen obligator...
# 29    EKSD - Amt für deutschsprachigen obligatorisch...
# ...                                                 ...
# 1563      EKSD - Amt für Unterricht der Sekundarstufe 2
# 1564                          EKSD - Amt für Ressourcen
# 1565  EKSD - Amt für französischsprachigen obligator...
# 1566  ILFD - Landwirtschaftliches Institut des Kanto...
# 1567  ILFD - Generalsekretariat, ILFD - Generalsekre...
# 1568                            FIND - Finanzverwaltung
# 1569  EKSD - Amt für französischsprachigen obligator...
# 1570             FIND - Grundbuchamt des Greyerzbezirks
# 1571                      SJD - Freiburger Strafanstalt
# 1572  ILFD - Amt für Wald und Natur, ILFD - Amt für ...
# 1573                              EKSD - Amt für Kultur
# 1574                                  RUBD - Tiefbauamt
# 1575                         EKSD - Amt für Archäologie
# 1576                      SJD - Freiburger Strafanstalt
# 1577                      ILFD - Amt für Landwirtschaft
# 1578                    SK - Sekretariat des Staatsrats
# 1579                        VWD - Amt für Berufsbildung
# 1580  EKSD - Amt für Ressourcen, EKSD - Amt für Ress...
# 1581                           GSD - Generalsekretariat
# 1582                           ILFD - Amt für Gemeinden
# 1583                              EKSD - Amt für Kultur
# 1584                        VWD - Amt für Berufsbildung
# 1585  VWD - Amt für Berufsbildung, VWD - Amt für Ber...
# 1586  GSD - Kantonale Sozialversicherungsanstalt, GS...
# 1587                        VWD - Amt für Berufsbildung
# 1588                                  RUBD - Hochbauamt
# 1589                      ILFD - Amt für Landwirtschaft
# 1590                              RUBD - Amt für Umwelt
# 1591                        VWD - Amt für Berufsbildung
# 1592           FIND - Amt für Personal und Organisation
#
#                                             6 Abteilung  \
# 0                                          Staatsarchiv
# 1                                  Technische Abteilung
# 2                                     Finanzinspektorat
# 3       Abteilung Institutionen und Rechtsangelenheiten
# 4                                        Kantonsarztamt
# 5       Sektor Faune, Biodiversität, Jagd und Fischerei
# 6                  Wirtschaftsförderung Kanton Freiburg
# 7                                            Sportarten
# 8                                    Handelsregisteramt
# 9                                         Amt für Sport
# 10                           Pädagogische Berater/innen
# 11                         Invalidenversicherungsstelle
# 12                                    Sozialvorsorgeamt
# 13                                           Verwaltung
# 14                       Kantonale Lehrmittelverwaltung
# 15                             Sektion Labor und Stoffe
# 16                                    Kollegium Gambach
# 17    Pädagogische Mitarbeit, Inspektorat für den de...
# 18                                        Sektor Pflege
# 19                               Pädagogische Mitarbeit
# 20                                   Generalsekretariat
# 21                                     Pflanzenbau (PB)
# 22                         Invalidenversicherungsstelle
# 23                                   Allgemeine Dienste
# 24                  Kantons- und Universitätsbibliothek
# 25    Direktzahlungen, Allgemeine Dienste, Produktef...
# 26                               Musée romain de Vallon
# 27                      Amt für Vermessung und Geomatik
# 28    Koordination für Schüleraustausch des Kantons ...
# 29    Koordination für Schüleraustausch des Kantons ...
# ...                                                 ...
# 1563                                          Direktion
# 1564  Französischsprachige Lehrpersonen des Kinderga...
# 1565                               PS Region von Murten
# 1566                        Schulgärten von Grangeneuve
# 1567     Generalsekretariat, Verwaltung der Staatsreben
# 1568                                   Finanzverwaltung
# 1569                              PS Le Flon, St-Martin
# 1570                    Grundbuchamt des Greyerzbezirks
# 1571                             Verwaltung und Empfang
# 1572   Zentrale Dienste, Sektor Verwaltung und Finanzen
# 1573                    Museum für Kunst und Geschichte
# 1574                                              SIERA
# 1575        Ausgrabungen, Forschungen und Publikationen
# 1576                             Verwaltung und Empfang
# 1577           Produkteförderung, Viehzucht und Weinbau
# 1578                  Administration und Beglaubigungen
# 1579          Gewerbliche und Industrielle Berufsschule
# 1580  Deutschsprachige Lehrpersonen der obligatorisc...
# 1581                                 Generalsekretariat
# 1582                                  Amt für Gemeinden
# 1583                Kantons- und Universitätsbibliothek
# 1584                                       FRee Trading
# 1585      Direktion und Sekretariat, Bereich Ausbildung
# 1586  Kantonale Ausgleichskasse AH/IV/EO, Kantonale ...
# 1587                                          Réception
# 1588                               Technische Abteilung
# 1589     Landwirtschaftliche Gebäude und Betriebshilfen
# 1590                       Sektion Abfall und Altlasten
# 1591                                           free win
# 1592                                  Gehaltsverwaltung
#
#                                              7 Funktion
# 0                                           Sekretariat
# 1                                           Architektin
# 2                              Adjunkt der Dienstchefin
# 3                     Höherer Verwaltungssachbearbeiter
# 4                               Adjunkt des Dienstchefs
# 5      Wissenschaftlicher Mitarbeiter Waldbiodiversität
# 6                                         Projektleiter
# 7                                                Kegeln
# 8                              Sekretariat und Schalter
# 9                             Pädagogischer Mitarbeiter
# 10                 Körper und Bewegung, Zyklus 1, 2 & 3
# 11                        sektionschef Zentrale Dienste
# 12                                         Dienstchefin
# 13                                          HR-Fachfrau
# 14                                    Direktionsadjunkt
# 15          Sektorchef Wasserkontrollen und Chemikalien
# 16                                          Vorsteherin
# 17    Pädagogische Beraterin: Sprachförderung Eingan...
# 18                                       Pflegefachfrau
# 19                            Pädagogischer Mitarbeiter
# 20                                      Generalsekretär
# 21                     Verantwortlicher für Pflanzenbau
# 22                          Sektionschefin Rechtsdienst
# 23                          Verwaltungssachbearbeiterin
# 24    Verantwortliche für Buchbinderei und Konservie...
# 25    Regionalverantwortlicher Unterer Saanebezirk, ...
# 26                                    Kon­ser­va­to­rin
# 27                                   Verwaltungsadjunkt
# 28                                        Coordinatrice
# 29                                        Coordinatrice
# ...                                                 ...
# 1563                                        Vorsteherin
# 1564                                         Sekretärin
# 1565                                     Schulleiter-in
# 1566                              Gemüse- Blumengärtner
# 1567                  Buchhaltung, Verwaltungsadjunktin
# 1568                              Staatsschatzverwalter
# 1569                                     Schulleiter-in
# 1570                                         Sekretärin
# 1571                         Fachmann für Justizvollzug
# 1572  Sektorchefin Verwaltung und Finanzen, Sektorch...
# 1573                              Technischer Assistent
# 1574                     Stellv. Zentrumsleiter Vaulruz
# 1575               Verantwortlicher für das Fotoatelier
# 1576                         Fachmann für Justizvollzug
# 1577                                       Sektionschef
# 1578                                    Verantwortliche
# 1579                        Verwaltungssachbearbeiterin
# 1580  Adjunkt der Dienstchefin, Adjunkt der Dienstch...
# 1581                              Direktionsassistentin
# 1582                                          Revisorin
# 1583  Sektorchefin, Sammlungen und kulturelle Aktivi...
# 1584                                           Lernende
# 1585  Bereichsleiter Ausbildung, Bereichsleiter Ausb...
# 1586  Sektionschef Beiträge, Wissenschaftlicher Mita...
# 1587                        Receptionistin-Telefonistin
# 1588                                                  *
# 1589                         Technischer Sachbearbeiter
# 1590                                          Altlasten
# 1591                                         Ausbildner
# 1592                            Verwaltungsangestellter
#
# [1593 rows x 7 columns]

# %% [markdown]
# ### Herr / Frau Zuordnung

# %%
# Weil das oben so toll geklappt hat kopiere ich den Code von oben hierhin, damit ich oben nichts kaputt mache
# Sachen vorbereiten

data = {'page': '1',
        'pageSize': '50',  # nur 50 um den Code erst zu testen
        'mainSearchText': '*'
       }

cookies = {'ASP.NET_SessionId': 'nt4pmcae3gesz4kk41h2lang'}

url = 'http://appl.fr.ch/ate/Person/FilterGridWithIds'

sub_base = 'http://appl.fr.ch/ate/Person/Detail/'

# Zugriff auf die Webseite

response = requests.post(url, data=data, cookies=cookies)
response_as_json = json.loads(response.text)

# For Loop

verzeichnis = []

for person in response_as_json['Data']:
    thisperson = {}
    thisperson['1 Name'] = person['DisplayName'] if not person['DisplayName'] is None else ''
    thisperson['2 ID'] = person['Id'] if not person['Id'] is None else ''
    thisperson['3 Email'] = person['Email'] if not person['Email'] is None else ''
    thisperson['4 Direktion'] = person['Roles'][0]['DirectionName'] if not person['Roles'] is None and len(person['Roles']) > 0 else ''
    thisperson['5 Sektion'] = person['UnitsDisplay'] if not person['UnitsDisplay'] is None else ''
    thisperson['6 Abteilung'] = person['UnitsExports'] if not person['UnitsExports'] is None else ''
    thisperson['7 Funktion'] = person['RolesDisplay'] if not person['RolesDisplay'] is None else ''
    
    # Uuund jetzt das Sub-Page Aufrufen.
    sub_url = sub_base + str(thisperson['2 ID'])
    
    #r = requests.get(sub_url)
    #soup = BeautifulSoup(r.content, 'lxml')
    
    
    
    verzeichnis.append(thisperson)
    
pd.DataFrame(verzeichnis)

# %%
# Weil das alles sonst zu kompliziert ist, scrape ich erst einmal eine Sub-Page.

sub_url = 'http://appl.fr.ch/ate/Person/Detail/1544'

r = requests.get(sub_url)
soup = BeautifulSoup(r.content, 'lxml')

soup.find('legend')
# Out:
# <legend>
# Monsieur<span> </span>
# Christophe<span> </span>
# Ackermann    </legend>
